# %% [markdown]
# # Scenario 1. Regression design
#
# ## Strategy 2. Microbiome taxa associated with outcome $y$ are clusterd at phylum level and order levels.

# %%
R.version
library(tidyverse)
library(caret)
library(randomForest)
library(reticulate)
np <- import("numpy")
# Out:
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          3
# minor          5.3
# year           2019
# month          03
# day            11
# svn rev        76217
# language       R
# version.string R version 3.5.3 (2019-03-11)
# nickname       Great Truth
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
#
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin

# %% [markdown]
# ### Configuration

# %%
data_path = "./data/simulation/s1"
path_genus = "./data/genus48"
count_path = 'data/simulation/count/'

y_path = sprintf('%s/%s', data_path, 'y.csv')
tree_info_path = './data/genus48/genus48_dic.csv'
count_path = './data/simulation/count'
count_list_path = './data/simulation/gcount_list.csv'
idx_path = './data/simulation/s1/idx.csv'

num_classes = 0 # regression
tree_level_list = c('Genus', 'Family', 'Order', 'Class', 'Phylum')

# %%
# # Read phylogenetic tree information

# phylogenetic_tree_info = read.csv(tree_info_path)
# phylogenetic_tree_info = phylogenetic_tree_info %>% select(tree_level_list)

# print(sprintf('Phylogenetic tree level list: %s', str_c(phylogenetic_tree_info %>% colnames, collapse = ', ')))

# %% [markdown]
# ### Read dataset

# %% [markdown]
# #### Read training, test dataset

# %%
read_dataset <- function(x_path, y_path, sim){
    print(str_c('Load data for repetition ', sim))
    x = read.csv(x_path)
    y = read.csv(y_path)[,sim]
    x = (x - max(x)) / (max(x) - min(x))

    idxs = idxs_total[, sim]
    remain_idxs = setdiff(seq(1, dim(x)[1]), idxs)

    x_train = x[idxs,]
    x_test = x[remain_idxs,]
    y_train = y[idxs]
    y_test = y[remain_idxs]
    
    return (list(x_train, x_test, y_train, y_test))
}

# %%
idxs_total = read.csv(idx_path)
number_of_fold = dim(idxs_total)[2]; number_of_fold
x_list = read.csv(count_list_path, header = FALSE)
x_path = x_list$V1 %>% sprintf('%s/%s', count_path, .)
# Out:
# [1] 1000

# %% [markdown]
# #### Read true tree weight

# %%
tw_1 = np$load(sprintf('%s/tw_1.npy', data_path))

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Importance type
#
# * See <https://stats.stackexchange.com/questions/92419/relative-importance-of-a-set-of-predictors-in-a-random-forests-classification-in>
#
# Here are the definitions of the variable importance measures.
#
# - `type=1`: **Mean decrease in accuracy**
#     - The first measure is computed from permuting Out-of-bag (OOB) data.
#     - For each tree, the prediction error on the out-of-bag portion of the data is recorded (error rate for classification, MSE for regression). Then the same is done after permuting each predictor variable.
#     - The difference between the two are then averaged over all trees, and normalized by the standard deviation of the differences.
#     - If the standard deviation of the differences is equal to 0 for a variable, the division is not done (but the average is almost always equal to 0 in that case).
#
# - `type=2`: **Mean decrease in node impurity**
#     - The second measure is the total decrease in node impurities from splitting on the variable, averaged over all trees.
#     - For classification, the node impurity is measured by the Gini index.
#     - For regression, it is measured by residual sum of squares.
#
# ### Feature selection
#
# * `vi_f`: variable importance by Gini importance (`type=2`)
# * `relative_vi_f` : relative variable importance
# * `thrd`: threshold for relative variable importance
# * Select features which have relative variable importance `relative_vi_f` equal or larger than threshold `thrd`

# %% [markdown]
# ### Simulate for all $n$

# %%
random_forest_res <- function(fold, importance_type=2, fs_thrd = 0.1){
    print(sprintf('-----------------------------------------------------------------'))
    print(sprintf('Random Forest computation for %dth repetition', fold))

    dataset = read_dataset(x_path[fold], y_path, fold)
    x_train = dataset[[1]]
    x_test = dataset[[2]]
    y_train = dataset[[3]]
    y_test = dataset[[4]]

    fit.rf <- randomForest(y_train~.,data=x_train, ntree=1000,  mtry=10, importance=TRUE)
    train.pred <- fit.rf$predicted
    test.pred <- predict(fit.rf,x_test)

    train.mse <- mean((y_train - train.pred)^2)
    train.cor <- cor(y_train, train.pred)

    test.mse <- mean((y_test - test.pred)^2)
    test.cor <- cor(y_test, test.pred)
    
    # Feature selection
    ## variable importance
    vi_f = importance(fit.rf, type=importance_type)
    relative_vi_f <- vi_f / sum(vi_f)
    selected_genus <- ifelse(relative_vi_f >= fs_thrd, 1, 0)
    
    order <- order(relative_vi_f, decreasing = TRUE)
    sorted_relative_vi_f <- relative_vi_f[order]
    names(sorted_relative_vi_f) <- colnames(x_train)[order]
    print(sorted_relative_vi_f)

    fold_genus = apply(tw_1[fold,,], 1, sum)
    names(fold_genus) <- x_train %>% colnames

    fs_conf_table <- table(selected_genus, fold_genus)
    
    fs_sensitivity <- sensitivity(fs_conf_table) 
    fs_specificity <- specificity(fs_conf_table)
    fs_gmeasure <- sqrt(fs_sensitivity*fs_specificity)
    fs_accuracy <- sum(diag(fs_conf_table))/sum(fs_conf_table)

    print(sprintf('Train mse: %s, Train Correlation: %s', train.mse, train.cor))
    print(sprintf('Test mse: %s, Test Correlation: %s', test.mse, test.cor))
    print(sprintf('FS sensitivity: %s, FS sensitivity: %s, FS gmeasure: %s, FS accuracy: %s',
                  fs_sensitivity, fs_specificity, fs_gmeasure, fs_accuracy))
    
    return (c(train.mse, train.cor, test.mse, test.cor, fs_sensitivity, fs_specificity, fs_gmeasure, fs_accuracy))
}

# %%
set.seed(100)
# res <- sapply(seq(1,1), random_forest_res)
res <- sapply(seq(1,10), random_forest_res)
# res <- sapply(seq(1,number_of_fold), random_forest_res)
# Out:
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 1th repetition"
# [1] "Load data for repetition 1"
#                        Rothia                    Tropheryma
#                  0.3179222284                  0.1996831487
#                   Actinomyces             Propionibacterium
#                  0.0709248163                  0.0633942904
#                Pseudonocardia     TM7_genera_incertae_sedis
#                  0.0402605466                  0.0157466900
#                    Prevotella                 Streptococcus
#                  0.0134348494                  0.0134239684
#                 Fusobacterium               Corynebacterium
#                  0.0119166391                  0.0116946387
#                  Oribacterium                   Selenomonas
#                  0.0115832209                  0.0113137569
#                   Veillonella                     Treponema
#                  0.0112033316                  0.0111000410
#                Capnocytophaga                 Porphyromonas
#                  0.0107391263                  0.0105354194
#                 Campylobacter                       Gemella
#                  0.0101381008                  0.0101198064
#                     Catonella                 Lactobacillus
#                  0.0100203120                  0.0099591823
#                     Atopobium                Granulicatella
#                  0.0095954758                  0.0093903242
#     OD1_genera_incertae_sedis                    Parvimonas
#                  0.0093880227                  0.0090175434
#                    Filifactor                   Megasphaera
#                  0.0088034940                  0.0080845839
#                Flavobacterium                     Neisseria
#                  0.0071732775                  0.0071646459
#                   Haemophilus                 Solobacterium
#                  0.0064084832                  0.0063439757
#                      Moryella                      Sneathia
#                  0.0061364053                  0.0057678939
#              Methylobacterium                  Sphingomonas
#                  0.0050053776                  0.0049407876
#                  Burkholderia                Staphylococcus
#                  0.0048706967                  0.0048605299
#                Microbacterium                  Bdellovibrio
#                  0.0029947006                  0.0029382472
#              Chryseobacterium                     Rhizobium
#                  0.0027159173                  0.0019979132
#                     Moraxella                   Bacteroides
#                  0.0018978045                  0.0017446575
#                Fastidiosipila                    Paracoccus
#                  0.0015618769                  0.0014373418
#                Bradyrhizobium                  Streptophyta
#                  0.0013684625                  0.0012547545
#                    Finegoldia Lachnospiracea_incertae_sedis
#                  0.0011097162                  0.0009129768
# [1] "Train mse: 0.56041343089407, Train Correlation: 0.932622508771498"
# [1] "Test mse: 0.643663222961741, Test Correlation: 0.923345362186333"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 2th repetition"
# [1] "Load data for repetition 2"
#                        Rothia                    Tropheryma
#                  0.3062618031                  0.2128886643
#             Propionibacterium                   Actinomyces
#                  0.0646157744                  0.0565406344
#                Pseudonocardia                    Prevotella
#                  0.0350078751                  0.0162137594
#                 Fusobacterium                   Veillonella
#                  0.0122746401                  0.0119350994
#                     Treponema                 Streptococcus
#                  0.0118955755                  0.0118257312
#     TM7_genera_incertae_sedis                Granulicatella
#                  0.0117900560                  0.0116385662
#                   Selenomonas                     Catonella
#                  0.0114562687                  0.0112265112
#                 Porphyromonas                Capnocytophaga
#                  0.0112237119                  0.0111977242
#     OD1_genera_incertae_sedis                       Gemella
#                  0.0105858276                  0.0105458148
#               Corynebacterium                   Megasphaera
#                  0.0104900194                  0.0096781841
#                 Lactobacillus                 Campylobacter
#                  0.0095084001                  0.0094776913
#                     Atopobium                     Neisseria
#                  0.0090305477                  0.0080988389
#                  Oribacterium                Staphylococcus
#                  0.0080835140                  0.0079955112
#                    Parvimonas                Flavobacterium
#                  0.0079062897                  0.0074171523
#                  Burkholderia                   Haemophilus
#                  0.0070956458                  0.0068849424
#                 Solobacterium                      Moryella
#                  0.0065396434                  0.0062360029
#                  Sphingomonas                      Sneathia
#                  0.0061564928                  0.0061251651
#              Methylobacterium                     Moraxella
#                  0.0048692902                  0.0047429945
#                    Paracoccus                    Filifactor
#                  0.0040249799                  0.0038564877
#                  Bdellovibrio                  Streptophyta
#                  0.0036753510                  0.0035169311
#                   Bacteroides                     Rhizobium
#                  0.0034499633                  0.0033801542
#                Bradyrhizobium                Microbacterium
#                  0.0033148142                  0.0031735314
#              Chryseobacterium                    Finegoldia
#                  0.0030235692                  0.0014011085
# Lachnospiracea_incertae_sedis                Fastidiosipila
#                  0.0009081064                  0.0008146396
# [1] "Train mse: 0.620336492930386, Train Correlation: 0.913571191203445"
# [1] "Test mse: 0.601666376895113, Test Correlation: 0.933150266668738"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 3th repetition"
# [1] "Load data for repetition 3"
#                        Rothia                    Tropheryma
#                   0.308025924                   0.226005332
#                   Actinomyces             Propionibacterium
#                   0.072348234                   0.052112483
#                Pseudonocardia     TM7_genera_incertae_sedis
#                   0.036127239                   0.017493688
#                    Prevotella                 Campylobacter
#                   0.015010530                   0.012065718
#                   Selenomonas                   Veillonella
#                   0.011536639                   0.011450188
#                      Sneathia                 Fusobacterium
#                   0.010837099                   0.010790582
#                 Lactobacillus               Corynebacterium
#                   0.010288502                   0.010198210
#                     Treponema                 Streptococcus
#                   0.010072117                   0.010041614
#                 Porphyromonas                     Atopobium
#                   0.009780546                   0.009634707
#                    Parvimonas     OD1_genera_incertae_sedis
#                   0.009309841                   0.009280965
#                     Catonella                       Gemella
#                   0.008920417                   0.008889261
#                Capnocytophaga                     Neisseria
#                   0.008810409                   0.008686202
#                Granulicatella                   Megasphaera
#                   0.008338968                   0.008146020
#                  Oribacterium                      Moryella
#                   0.007167132                   0.007106125
#                Staphylococcus                   Haemophilus
#                   0.006418076                   0.006342302
#                 Solobacterium                Flavobacterium
#                   0.005881382                   0.005829799
#                Microbacterium                    Filifactor
#                   0.005316868                   0.005281645
#                  Burkholderia                  Sphingomonas
#                   0.005162809                   0.004655030
#              Methylobacterium              Chryseobacterium
#                   0.003972741                   0.003445846
#                   Bacteroides                  Bdellovibrio
#                   0.003004819                   0.002789953
#                     Rhizobium                     Moraxella
#                   0.002661640                   0.002059716
#                    Finegoldia                Bradyrhizobium
#                   0.001895864                   0.001750828
#                    Paracoccus                Fastidiosipila
#                   0.001646343                   0.001325134
# Lachnospiracea_incertae_sedis                  Streptophyta
#                   0.001079251                   0.001005263
# [1] "Train mse: 0.574587554100399, Train Correlation: 0.928625902282782"
# [1] "Test mse: 0.522664219080196, Test Correlation: 0.930088968230043"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 4th repetition"
# [1] "Load data for repetition 4"
#                        Rothia                    Tropheryma
#                   0.316645845                   0.181970473
#             Propionibacterium                   Actinomyces
#                   0.076355691                   0.061031620
#                Pseudonocardia                 Streptococcus
#                   0.037915950                   0.016692171
#                    Prevotella                     Treponema
#                   0.014868360                   0.012656083
#                 Campylobacter                Capnocytophaga
#                   0.012555269                   0.012179671
#                 Fusobacterium                 Porphyromonas
#                   0.011861638                   0.011336466
#                   Selenomonas                     Catonella
#                   0.011260892                   0.011208535
#                   Veillonella                     Atopobium
#                   0.011157243                   0.010686122
#                       Gemella                 Lactobacillus
#                   0.010612896                   0.010611887
#     TM7_genera_incertae_sedis                Granulicatella
#                   0.010611020                   0.010259406
#     OD1_genera_incertae_sedis               Corynebacterium
#                   0.010179567                   0.009751162
#                      Moryella                    Parvimonas
#                   0.009456407                   0.009321629
#                     Neisseria                   Megasphaera
#                   0.008692475                   0.007607092
#                Staphylococcus                Microbacterium
#                   0.007070270                   0.006816745
#                  Oribacterium                 Solobacterium
#                   0.006678080                   0.006647021
#                Flavobacterium                    Filifactor
#                   0.006617644                   0.006546027
#                      Sneathia                  Burkholderia
#                   0.006343091                   0.006331161
#                   Haemophilus              Chryseobacterium
#                   0.006197600                   0.004828190
#              Methylobacterium                  Sphingomonas
#                   0.004823931                   0.004470602
#                  Bdellovibrio                     Moraxella
#                   0.004118653                   0.003053820
#                   Bacteroides                Fastidiosipila
#                   0.002916542                   0.001726045
#                Bradyrhizobium                    Finegoldia
#                   0.001467447                   0.001290871
#                     Rhizobium                    Paracoccus
#                   0.001265533                   0.001152878
# Lachnospiracea_incertae_sedis                  Streptophyta
#                   0.001122115                   0.001030161
# [1] "Train mse: 0.621198751449717, Train Correlation: 0.923353980350844"
# [1] "Test mse: 0.489864183231227, Test Correlation: 0.932809484229685"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 5th repetition"
# [1] "Load data for repetition 5"
#                        Rothia                    Tropheryma
#                   0.336631130                   0.181049320
#             Propionibacterium                   Actinomyces
#                   0.068921518                   0.061611065
#                Pseudonocardia                 Streptococcus
#                   0.043534944                   0.012506198
#                    Prevotella                 Porphyromonas
#                   0.012472429                   0.012033950
#                     Treponema                       Gemella
#                   0.011633375                   0.011615805
#     TM7_genera_incertae_sedis                     Catonella
#                   0.011542120                   0.011490841
#                   Selenomonas                 Fusobacterium
#                   0.011160678                   0.011092189
#                   Veillonella     OD1_genera_incertae_sedis
#                   0.010683152                   0.010243922
#                Granulicatella                 Lactobacillus
#                   0.009691264                   0.009501402
#                Capnocytophaga                 Campylobacter
#                   0.009411268                   0.009310333
#               Corynebacterium                     Atopobium
#                   0.009262081                   0.009016490
#                   Megasphaera                     Neisseria
#                   0.008993801                   0.008659337
#                      Moryella                    Parvimonas
#                   0.008152071                   0.007933033
#                  Sphingomonas                      Sneathia
#                   0.007627538                   0.007195937
#                Staphylococcus                   Haemophilus
#                   0.006651311                   0.006452909
#                 Solobacterium                  Oribacterium
#                   0.006344636                   0.005961381
#                    Filifactor                  Bdellovibrio
#                   0.005630453                   0.005522090
#                Flavobacterium              Methylobacterium
#                   0.005397044                   0.005149868
#                  Burkholderia                Microbacterium
#                   0.005024144                   0.003542218
#                     Rhizobium              Chryseobacterium
#                   0.003451367                   0.003221109
#                     Moraxella                   Bacteroides
#                   0.002587526                   0.002461448
#                Bradyrhizobium                  Streptophyta
#                   0.002289938                   0.002215956
#                    Finegoldia                Fastidiosipila
#                   0.001448030                   0.001234595
#                    Paracoccus Lachnospiracea_incertae_sedis
#                   0.001231398                   0.001205388
# [1] "Train mse: 0.607561218407389, Train Correlation: 0.926283682830079"
# [1] "Test mse: 0.674782357631757, Test Correlation: 0.915941684687177"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 6th repetition"
# [1] "Load data for repetition 6"
#                        Rothia                    Tropheryma
#                  0.3427670625                  0.1858991303
#                   Actinomyces             Propionibacterium
#                  0.0767684680                  0.0524948405
#                Pseudonocardia                 Streptococcus
#                  0.0319776276                  0.0172231261
#                    Prevotella     TM7_genera_incertae_sedis
#                  0.0162056319                  0.0129278954
#                   Veillonella                 Fusobacterium
#                  0.0127977886                  0.0124304621
#               Corynebacterium                 Campylobacter
#                  0.0114471656                  0.0113224781
#                       Gemella                     Treponema
#                  0.0112566000                  0.0107148963
#                Granulicatella                   Selenomonas
#                  0.0105102629                  0.0101711925
#                Capnocytophaga                 Porphyromonas
#                  0.0100162897                  0.0099836744
#                 Lactobacillus                Staphylococcus
#                  0.0096547938                  0.0092454253
#                     Catonella                    Parvimonas
#                  0.0087717916                  0.0086983870
#                     Neisseria     OD1_genera_incertae_sedis
#                  0.0085135614                  0.0081495747
#                     Atopobium                  Oribacterium
#                  0.0079452666                  0.0079156134
#                      Sneathia                      Moryella
#                  0.0069604848                  0.0067583090
#                   Megasphaera                Flavobacterium
#                  0.0065262002                  0.0065160543
#                  Sphingomonas                  Burkholderia
#                  0.0063237068                  0.0062178389
#                 Solobacterium              Methylobacterium
#                  0.0058927195                  0.0056669532
#                   Haemophilus              Chryseobacterium
#                  0.0055148423                  0.0038499646
#                    Filifactor                Microbacterium
#                  0.0036676873                  0.0032171815
#                  Bdellovibrio                   Bacteroides
#                  0.0027712153                  0.0025804397
#                     Moraxella                  Streptophyta
#                  0.0021630656                  0.0018947045
#                     Rhizobium                Bradyrhizobium
#                  0.0018735831                  0.0017638596
#                    Finegoldia                Fastidiosipila
#                  0.0010830399                  0.0010036281
#                    Paracoccus Lachnospiracea_incertae_sedis
#                  0.0009745057                  0.0009710097
# [1] "Train mse: 0.568573195723176, Train Correlation: 0.931963237110121"
# [1] "Test mse: 0.556678881269405, Test Correlation: 0.929143169724464"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 7th repetition"
# [1] "Load data for repetition 7"
#                        Rothia                    Tropheryma
#                  0.3308946853                  0.1883887534
#                   Actinomyces             Propionibacterium
#                  0.0672335573                  0.0648225139
#                Pseudonocardia                 Streptococcus
#                  0.0424944664                  0.0172796147
#                       Gemella                 Fusobacterium
#                  0.0172035671                  0.0133035753
#                 Porphyromonas                    Prevotella
#                  0.0131833387                  0.0124078681
#                 Campylobacter                     Treponema
#                  0.0120506234                  0.0119008980
#     TM7_genera_incertae_sedis                   Selenomonas
#                  0.0118826126                  0.0115054706
#                   Veillonella                    Parvimonas
#                  0.0109960621                  0.0100818553
#                     Catonella                 Lactobacillus
#                  0.0099998339                  0.0098528741
#                Capnocytophaga                Granulicatella
#                  0.0090621041                  0.0087448057
#     OD1_genera_incertae_sedis               Corynebacterium
#                  0.0081652454                  0.0081563006
#                      Sneathia                     Atopobium
#                  0.0081142367                  0.0078280055
#                      Moryella                     Neisseria
#                  0.0072024294                  0.0070832620
#                  Oribacterium                Flavobacterium
#                  0.0068790536                  0.0066359520
#                   Megasphaera                  Burkholderia
#                  0.0061744280                  0.0060565209
#                Staphylococcus                   Haemophilus
#                  0.0058919074                  0.0056409811
#                 Solobacterium                  Sphingomonas
#                  0.0054271924                  0.0052260070
#              Methylobacterium              Chryseobacterium
#                  0.0045003600                  0.0037877662
#                    Filifactor                  Bdellovibrio
#                  0.0037701933                  0.0028571129
#                   Bacteroides                     Moraxella
#                  0.0025923465                  0.0024561431
#                  Streptophyta                Microbacterium
#                  0.0021276943                  0.0019223344
#                Bradyrhizobium                     Rhizobium
#                  0.0017694313                  0.0017265648
#                    Finegoldia                Fastidiosipila
#                  0.0014086485                  0.0013997694
# Lachnospiracea_incertae_sedis                    Paracoccus
#                  0.0010117674                  0.0008992658
# [1] "Train mse: 0.556009472570016, Train Correlation: 0.93385906057846"
# [1] "Test mse: 0.530527350963533, Test Correlation: 0.93630860040158"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 8th repetition"
# [1] "Load data for repetition 8"
#                        Rothia                    Tropheryma
#                  0.3431234757                  0.2009219472
#                   Actinomyces             Propionibacterium
#                  0.0533716312                  0.0520181657
#                Pseudonocardia                 Streptococcus
#                  0.0409268781                  0.0162433924
#                    Prevotella                     Treponema
#                  0.0160598673                  0.0119747254
#     TM7_genera_incertae_sedis                 Porphyromonas
#                  0.0118287644                  0.0108151268
#                 Fusobacterium                 Campylobacter
#                  0.0106611912                  0.0105225966
#                Capnocytophaga                 Lactobacillus
#                  0.0101052831                  0.0099480847
#                   Veillonella                Granulicatella
#                  0.0099122490                  0.0098852304
#                       Gemella     OD1_genera_incertae_sedis
#                  0.0098193333                  0.0093163512
#                   Selenomonas                     Catonella
#                  0.0092845284                  0.0091618033
#                    Parvimonas                   Megasphaera
#                  0.0090338983                  0.0089312826
#                     Neisseria                  Sphingomonas
#                  0.0084799589                  0.0079223484
#               Corynebacterium                     Atopobium
#                  0.0078802217                  0.0071812508
#                      Moryella                   Haemophilus
#                  0.0071653835                  0.0071610675
#                  Oribacterium                  Burkholderia
#                  0.0070524082                  0.0068703910
#                 Solobacterium                Flavobacterium
#                  0.0065048675                  0.0061857758
#                      Sneathia                Staphylococcus
#                  0.0060965979                  0.0054383412
#                Microbacterium              Methylobacterium
#                  0.0048161385                  0.0046975403
#              Chryseobacterium                    Filifactor
#                  0.0042868745                  0.0042522913
#                     Rhizobium                    Paracoccus
#                  0.0042022988                  0.0036755684
#                  Bdellovibrio                   Bacteroides
#                  0.0031471559                  0.0028256763
# Lachnospiracea_incertae_sedis                     Moraxella
#                  0.0024083452                  0.0020092179
#                Fastidiosipila                Bradyrhizobium
#                  0.0019674760                  0.0018088280
#                  Streptophyta                    Finegoldia
#                  0.0014325671                  0.0006656033
# [1] "Train mse: 0.568757747784742, Train Correlation: 0.925152257229221"
# [1] "Test mse: 0.661232547454556, Test Correlation: 0.917855867658133"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 9th repetition"
# [1] "Load data for repetition 9"
#                        Rothia                    Tropheryma
#                  0.3198570902                  0.2121341201
#                   Actinomyces             Propionibacterium
#                  0.0654104248                  0.0574329454
#                Pseudonocardia                 Porphyromonas
#                  0.0484227866                  0.0163584049
#                 Streptococcus                    Prevotella
#                  0.0145465527                  0.0139011085
#                 Fusobacterium                     Treponema
#                  0.0121595586                  0.0113151116
#                       Gemella                 Campylobacter
#                  0.0108451798                  0.0100810565
#     TM7_genera_incertae_sedis                     Catonella
#                  0.0099509111                  0.0095946933
#                   Veillonella                Capnocytophaga
#                  0.0095221002                  0.0094258755
#     OD1_genera_incertae_sedis                    Parvimonas
#                  0.0093777659                  0.0091619659
#                   Selenomonas                     Atopobium
#                  0.0091071132                  0.0090650719
#                     Neisseria                Granulicatella
#                  0.0090216415                  0.0087844867
#               Corynebacterium                      Sneathia
#                  0.0087483764                  0.0085954136
#                 Lactobacillus                Flavobacterium
#                  0.0083112232                  0.0074738107
#                   Megasphaera                   Haemophilus
#                  0.0070179928                  0.0070048051
#                      Moryella                  Oribacterium
#                  0.0064395110                  0.0060861388
#                Staphylococcus                 Solobacterium
#                  0.0056202141                  0.0053459876
#                  Burkholderia              Methylobacterium
#                  0.0052651161                  0.0039967519
#              Chryseobacterium                  Streptophyta
#                  0.0036028055                  0.0035140861
#                  Bdellovibrio                  Sphingomonas
#                  0.0034775857                  0.0034498508
#                Microbacterium                     Moraxella
#                  0.0034307279                  0.0031576496
#                    Filifactor                Bradyrhizobium
#                  0.0030530881                  0.0028115868
#                    Finegoldia                   Bacteroides
#                  0.0018040123                  0.0017379263
# Lachnospiracea_incertae_sedis                     Rhizobium
#                  0.0014582291                  0.0013770180
#                    Paracoccus                Fastidiosipila
#                  0.0011422696                  0.0006018581
# [1] "Train mse: 0.564839488126747, Train Correlation: 0.932338624494699"
# [1] "Test mse: 0.547021038849762, Test Correlation: 0.930310481510756"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 10th repetition"
# [1] "Load data for repetition 10"
#                        Rothia                    Tropheryma
#                  0.3454962326                  0.1966605210
#                   Actinomyces             Propionibacterium
#                  0.0643405829                  0.0604843498
#                Pseudonocardia     TM7_genera_incertae_sedis
#                  0.0362779293                  0.0169955630
#                   Veillonella                 Porphyromonas
#                  0.0144111814                  0.0117172022
#                 Streptococcus                    Prevotella
#                  0.0115058349                  0.0114815639
#                     Treponema                 Fusobacterium
#                  0.0113313341                  0.0112094973
#                       Gemella     OD1_genera_incertae_sedis
#                  0.0100690005                  0.0098849001
#                Granulicatella                Capnocytophaga
#                  0.0098250997                  0.0098217197
#               Corynebacterium                 Campylobacter
#                  0.0097531082                  0.0096319032
#                     Catonella                 Lactobacillus
#                  0.0095903162                  0.0095343722
#                   Selenomonas                 Solobacterium
#                  0.0090752715                  0.0084370826
#                     Neisseria                     Atopobium
#                  0.0083848759                  0.0075420276
#                    Parvimonas                      Moryella
#                  0.0074777773                  0.0072628624
#                    Filifactor                  Oribacterium
#                  0.0071857522                  0.0061071142
#                   Megasphaera                  Burkholderia
#                  0.0058900734                  0.0057216315
#                Staphylococcus                      Sneathia
#                  0.0057139575                  0.0057045171
#                   Haemophilus                Flavobacterium
#                  0.0054322341                  0.0053468923
#              Methylobacterium                  Sphingomonas
#                  0.0048106637                  0.0045469528
#                  Bdellovibrio              Chryseobacterium
#                  0.0039893100                  0.0039148140
#                   Bacteroides                Microbacterium
#                  0.0029762887                  0.0024947283
#                     Rhizobium                     Moraxella
#                  0.0022147590                  0.0021267919
#                  Streptophyta                    Paracoccus
#                  0.0019440546                  0.0016618645
#                Bradyrhizobium                    Finegoldia
#                  0.0013243426                  0.0010345323
# Lachnospiracea_incertae_sedis                Fastidiosipila
#                  0.0009045923                  0.0007520235
# [1] "Train mse: 0.537674837033514, Train Correlation: 0.931007961774421"
# [1] "Test mse: 0.55078853671716, Test Correlation: 0.925459957568736"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"

# %%
results_table = res %>% t %>% data.frame
colnames(results_table) = c('Training MSE', 'Training Correlation', 'Test MSE', 'Test Correlation', 
                            'Taxa selection sensitivity','Taxa selection sensitivity',
                            'Taxa selection gmeasure', 'Taxa selection accuracy')
results_table
# Out:
#    Training MSE Training Correlation Test MSE  Test Correlation
# 1  0.5604134    0.9326225            0.6436632 0.9233454
# 2  0.6203365    0.9135712            0.6016664 0.9331503
# 3  0.5745876    0.9286259            0.5226642 0.9300890
# 4  0.6211988    0.9233540            0.4898642 0.9328095
# 5  0.6075612    0.9262837            0.6747824 0.9159417
# 6  0.5685732    0.9319632            0.5566789 0.9291432
# 7  0.5560095    0.9338591            0.5305274 0.9363086
# 8  0.5687577    0.9251523            0.6612325 0.9178559
# 9  0.5648395    0.9323386            0.5470210 0.9303105
# 10 0.5376748    0.9310080            0.5507885 0.9254600
#    Taxa selection sensitivity Taxa selection sensitivity
# 1  1                          0.1052632
# 2  1                          0.1052632
# 3  1                          0.1052632
# 4  1                          0.1052632
# 5  1                          0.1052632
# 6  1                          0.1052632
# 7  1                          0.1052632
# 8  1                          0.1052632
# 9  1                          0.1052632
# 10 1                          0.1052632
#    Taxa selection gmeasure Taxa selection accuracy
# 1  0.3244428               0.6458333
# 2  0.3244428               0.6458333
# 3  0.3244428               0.6458333
# 4  0.3244428               0.6458333
# 5  0.3244428               0.6458333
# 6  0.3244428               0.6458333
# 7  0.3244428               0.6458333
# 8  0.3244428               0.6458333
# 9  0.3244428               0.6458333
# 10 0.3244428               0.6458333

# %%
print('Mean')
apply(results_table, 2, mean)
# Out:
# [1] "Mean"
#               Training MSE       Training Correlation
#                  0.5779952                  0.9278778
#                   Test MSE           Test Correlation
#                  0.5778889                  0.9274414
# Taxa selection sensitivity Taxa selection sensitivity
#                  1.0000000                  0.1052632
#    Taxa selection gmeasure    Taxa selection accuracy
#                  0.3244428                  0.6458333

# %%
print('SD')
apply(results_table, 2, sd)
# Out:
# [1] "SD"
#               Training MSE       Training Correlation
#                0.028500474                0.006149515
#                   Test MSE           Test Correlation
#                0.063599867                0.006691633
# Taxa selection sensitivity Taxa selection sensitivity
#                0.000000000                0.000000000
#    Taxa selection gmeasure    Taxa selection accuracy
#                0.000000000                0.000000000
