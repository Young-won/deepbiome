# %% [markdown]
# # Scenario 2. Binary classification

# %%
R.version
library(tidyverse)
library(caret)
library(randomForest)
library(reticulate)
library(mltools)
np <- import("numpy")
# Out:
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          3
# minor          5.3
# year           2019
# month          03
# day            11
# svn rev        76217
# language       R
# version.string R version 3.5.3 (2019-03-11)
# nickname       Great Truth
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
#
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
#
#
# Attaching package: ‘mltools’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     replace_na

# %% [markdown]
# ### Configuration

# %%
data_path = "./data/simulation/s2"
path_genus = "./data/genus48"
count_path = 'data/simulation/count/'

y_path = sprintf('%s/%s', data_path, 'y.csv')
tree_info_path = './data/genus48/genus48_dic.csv'
count_path = './data/simulation/count'
count_list_path = './data/simulation/gcount_list.csv'
idx_path = './data/simulation/s1/idx.csv'

num_classes = 0 # regression
tree_level_list = c('Genus', 'Family', 'Order', 'Class', 'Phylum')

# %%
# # Read phylogenetic tree information

# phylogenetic_tree_info = read.csv(tree_info_path)
# phylogenetic_tree_info = phylogenetic_tree_info %>% select(tree_level_list)

# print(sprintf('Phylogenetic tree level list: %s', str_c(phylogenetic_tree_info %>% colnames, collapse = ', ')))

# %% [markdown]
# ### Read dataset

# %% [markdown]
# #### Read training, test dataset

# %%
read_dataset <- function(x_path, y_path, sim){
    print(str_c('Load data for repetition ', sim))
    x = read.csv(x_path)
    y = read.csv(y_path)[,sim]
    x = (x - max(x)) / (max(x) - min(x))

    idxs = idxs_total[, sim]
    remain_idxs = setdiff(seq(1, dim(x)[1]), idxs)

    x_train = x[idxs,]
    x_test = x[remain_idxs,]
    y_train = y[idxs]
    y_test = y[remain_idxs]
    
    return (list(x_train, x_test, y_train, y_test))
}

# %%
idxs_total = read.csv(idx_path)
number_of_fold = dim(idxs_total)[2]; number_of_fold
x_list = read.csv(count_list_path, header = FALSE)
x_path = x_list$V1 %>% sprintf('%s/%s', count_path, .)
# Out:
# [1] 1000

# %% [markdown]
# #### Read true tree weight

# %%
tw_1 = np$load(sprintf('%s/tw_1.npy', data_path))

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Importance type
#
# * See <https://stats.stackexchange.com/questions/92419/relative-importance-of-a-set-of-predictors-in-a-random-forests-classification-in>
#
# Here are the definitions of the variable importance measures.
#
# - `type=1`: **Mean decrease in accuracy**
#     - The first measure is computed from permuting Out-of-bag (OOB) data.
#     - For each tree, the prediction error on the out-of-bag portion of the data is recorded (error rate for classification, MSE for regression). Then the same is done after permuting each predictor variable.
#     - The difference between the two are then averaged over all trees, and normalized by the standard deviation of the differences.
#     - If the standard deviation of the differences is equal to 0 for a variable, the division is not done (but the average is almost always equal to 0 in that case).
#
# - `type=2`: **Mean decrease in node impurity**
#     - The second measure is the total decrease in node impurities from splitting on the variable, averaged over all trees.
#     - For classification, the node impurity is measured by the Gini index.
#     - For regression, it is measured by residual sum of squares.
#
# ### Feature selection
#
# * `vi_f`: variable importance by Gini importance (`type=2`)
# * `relative_vi_f` : relative variable importance
# * `thrd`: threshold for relative variable importance
# * Select features which have relative variable importance `relative_vi_f` equal or larger than threshold `thrd`

# %% [markdown]
# ### Simulate for all $n$

# %%
random_forest_res <- function(fold, importance_type=2, fs_thrd = 0.1){
    print(sprintf('-----------------------------------------------------------------'))
    print(sprintf('Random Forest computation for %dth repetition', fold))

    dataset = read_dataset(x_path[fold], y_path, fold)
    x_train = dataset[[1]]
    x_test = dataset[[2]]
    y_train = dataset[[3]]
    y_test = dataset[[4]]
    
    # Binary classification
    y_train = factor(y_train, levels = c(0,1), ordered=TRUE)
    y_test = factor(y_test, levels = c(0,1), ordered=TRUE)

    fit.rf <- randomForest(y_train~.,data=x_train, ntree=1000,  mtry=10, importance=TRUE)
    train.pred <- fit.rf$predicted
    test.pred <- predict(fit.rf,x_test)

    train_conf <- table(train.pred, y_train)
    train_sensitivity <- sensitivity(train_conf)
    train_specificity <- specificity(train_conf)
    train_gmeasure <- sqrt(train_sensitivity*train_specificity)
    train_accuracy <- sum(diag(train_conf))/sum(train_conf)
    train_auc <- auc_roc(train.pred, y_train)

    test_conf <- table(test.pred, y_test)
    test_sensitivity <- sensitivity(test_conf)
    test_specificity <- specificity(test_conf)
    test_gmeasure <- sqrt(test_sensitivity*test_specificity)
    test_accuracy <- sum(diag(test_conf))/sum(test_conf)
    test_auc <- auc_roc(test.pred, y_test)
    
    # Feature selection
    ## variable importance
    vi_f = importance(fit.rf, type=importance_type)
    relative_vi_f <- vi_f / sum(vi_f)
    selected_genus <- ifelse(relative_vi_f >= fs_thrd, 1, 0)
    
    order <- order(relative_vi_f, decreasing = TRUE)
    sorted_relative_vi_f <- relative_vi_f[order]
    names(sorted_relative_vi_f) <- colnames(x_train)[order]
    print(sorted_relative_vi_f)

    fold_genus = apply(tw_1[fold,,], 1, sum)
    names(fold_genus) <- x_train %>% colnames

    fs_conf_table <- table(selected_genus, fold_genus)
    
    fs_sensitivity <- sensitivity(fs_conf_table) 
    fs_specificity <- specificity(fs_conf_table)
    fs_gmeasure <- sqrt(fs_sensitivity*fs_specificity)
    fs_accuracy <- sum(diag(fs_conf_table))/sum(fs_conf_table)

    print(sprintf('Train sensitivity: %s, Train sensitivity: %s, Train gmeasure: %s, Train accuracy: %s, Train AUC: %s',
                  train_sensitivity, train_specificity, train_gmeasure, train_accuracy, train_auc))
    print(sprintf('Test sensitivity: %s, Test sensitivity: %s, Test gmeasure: %s, Test accuracy: %s, Test AUC: %s',
                  test_sensitivity, test_specificity, test_gmeasure, test_accuracy, test_auc))
    print(sprintf('FS sensitivity: %s, FS sensitivity: %s, FS gmeasure: %s, FS accuracy: %s',
                  fs_sensitivity, fs_specificity, fs_gmeasure, fs_accuracy))
    
    return (c(train_sensitivity, train_specificity, train_gmeasure, train_accuracy, train_auc, 
              test_sensitivity, test_specificity, test_gmeasure, test_accuracy, test_auc,
              fs_sensitivity, fs_specificity, fs_gmeasure, fs_accuracy))
}

# %%
set.seed(100)
# res <- sapply(seq(1,1), random_forest_res)
res <- sapply(seq(1,10), random_forest_res)
# res <- sapply(seq(1,number_of_fold), random_forest_res)
# Out:
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 1th repetition"
# [1] "Load data for repetition 1"
#                        Rothia                  Oribacterium
#                   0.330196439                   0.110725797
#             Propionibacterium                    Tropheryma
#                   0.050529145                   0.050367816
#                      Moryella                   Actinomyces
#                   0.032971117                   0.026832935
#                    Filifactor                Pseudonocardia
#                   0.025765962                   0.018555369
#               Corynebacterium                     Treponema
#                   0.016087377                   0.015729644
#                 Porphyromonas                    Prevotella
#                   0.014964231                   0.014694758
#                 Streptococcus                 Campylobacter
#                   0.014018473                   0.013546102
#                     Neisseria                       Gemella
#                   0.013451405                   0.013444059
#                 Fusobacterium     TM7_genera_incertae_sedis
#                   0.013421796                   0.013058109
#                   Veillonella                   Selenomonas
#                   0.012682783                   0.011564576
#                   Megasphaera                 Lactobacillus
#                   0.011171611                   0.011101429
#                     Atopobium                Capnocytophaga
#                   0.010962957                   0.010680586
#                Granulicatella                Staphylococcus
#                   0.010453502                   0.010339429
#                    Parvimonas                     Catonella
#                   0.009820385                   0.009608279
#     OD1_genera_incertae_sedis                 Solobacterium
#                   0.009490304                   0.007856060
#                Flavobacterium                      Sneathia
#                   0.007646284                   0.007517175
#                  Sphingomonas              Chryseobacterium
#                   0.006991138                   0.006775761
#              Methylobacterium                  Burkholderia
#                   0.006705261                   0.006684104
#                   Haemophilus                  Streptophyta
#                   0.006587424                   0.006331244
#                Fastidiosipila                  Bdellovibrio
#                   0.004877050                   0.004596667
#                   Bacteroides                Microbacterium
#                   0.004154225                   0.003423527
#                    Paracoccus                    Finegoldia
#                   0.003211654                   0.002913112
# Lachnospiracea_incertae_sedis                Bradyrhizobium
#                   0.002577682                   0.001758407
#                     Rhizobium                     Moraxella
#                   0.001707706                   0.001449147
# [1] "Train sensitivity: 0.780172413793103, Train sensitivity: 0.971042471042471, Train gmeasure: 0.870391031967141, Train accuracy: 0.912, Train AUC: 0.875607442417787"
# [1] "Test sensitivity: 0.839506172839506, Test sensitivity: 0.988165680473373, Test gmeasure: 0.910807986650066, Test accuracy: 0.94, Test AUC: 0.913835926656439"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 2th repetition"
# [1] "Load data for repetition 2"
#                        Rothia                  Oribacterium
#                   0.290011016                   0.114508349
#             Propionibacterium                    Tropheryma
#                   0.057951116                   0.040137055
#                      Moryella                    Filifactor
#                   0.031571583                   0.027986566
#                 Porphyromonas                   Actinomyces
#                   0.023812180                   0.022445782
#                 Lactobacillus                   Veillonella
#                   0.021749066                   0.020990299
#     OD1_genera_incertae_sedis                   Selenomonas
#                   0.020189911                   0.018501255
#                    Prevotella                Pseudonocardia
#                   0.015794765                   0.015712940
#                 Streptococcus                     Catonella
#                   0.015118993                   0.015002931
#                     Treponema                Capnocytophaga
#                   0.013921536                   0.013607279
#                 Campylobacter                Granulicatella
#                   0.013373093                   0.013336627
#     TM7_genera_incertae_sedis                       Gemella
#                   0.013132668                   0.012870401
#                 Fusobacterium                     Atopobium
#                   0.012779963                   0.012396797
#               Corynebacterium                    Parvimonas
#                   0.011920134                   0.011378870
#                Staphylococcus                Flavobacterium
#                   0.009561538                   0.009556849
#                     Neisseria                   Haemophilus
#                   0.008868723                   0.008715323
#                  Burkholderia                      Sneathia
#                   0.008683352                   0.008349584

# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 4th repetition"
# [1] "Load data for repetition 4"
#                        Rothia                  Oribacterium
#                   0.314034161                   0.105380427
#             Propionibacterium                    Tropheryma
#                   0.064706485                   0.048649040
#                    Filifactor                      Moryella
#                   0.037020641                   0.028405971
#                   Actinomyces                 Streptococcus
#                   0.022380047                   0.021291269
#                Pseudonocardia                 Fusobacterium
#                   0.019154729                   0.016109285
#                       Gemella                 Porphyromonas
#                   0.015140013                   0.015095059
#     TM7_genera_incertae_sedis                     Treponema
#                   0.014938548                   0.014410449
#                   Veillonella                    Parvimonas
#                   0.014134359                   0.014038768
#                    Prevotella                   Selenomonas
#                   0.013872742                   0.012851381
#                 Lactobacillus                 Campylobacter
#                   0.012323981                   0.011462762
#     OD1_genera_incertae_sedis                   Haemophilus
#                   0.011416775                   0.011171323
#                     Catonella                Capnocytophaga
#                   0.010358030                   0.010289276
#                  Burkholderia                Granulicatella
#                   0.010110134                   0.010041320
#                     Neisseria               Corynebacterium
#                   0.009889344                   0.009750385
#                     Atopobium                   Megasphaera
#                   0.009076704                   0.009063076
#                  Sphingomonas                Staphylococcus
#                   0.007756554                   0.007419560
#              Methylobacterium                Flavobacterium
#                   0.007208698                   0.007079424
#                 Solobacterium                Microbacterium
#                   0.006747736                   0.006346680
#                      Sneathia                     Moraxella
#                   0.006167387                   0.005315969
#              Chryseobacterium                  Bdellovibrio
#                   0.005159709                   0.005159262
#                Fastidiosipila                Bradyrhizobium
#                   0.003350389                   0.002945001
# Lachnospiracea_incertae_sedis                    Paracoccus
#                   0.002838483                   0.002381228
#                  Streptophyta                     Rhizobium
#                   0.002307273                   0.002148535
#                   Bacteroides                    Finegoldia
#                   0.002010807                   0.001090823
# [1] "Train sensitivity: 0.804545454545455, Train sensitivity: 0.971698113207547, Train gmeasure: 0.884180581200202, Train accuracy: 0.922666666666667, Train AUC: 0.888121783876501"
# [1] "Test sensitivity: 0.860759493670886, Test sensitivity: 0.970760233918129, Test gmeasure: 0.914106715555246, Test accuracy: 0.936, Test AUC: 0.915759863794507"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 5th repetition"
# [1] "Load data for repetition 5"
#                        Rothia                  Oribacterium
#                   0.325907108                   0.105293654
#             Propionibacterium                    Filifactor
#                   0.049486798                   0.040171747
#                    Tropheryma                      Moryella
#                   0.035727232                   0.026223007
#                 Porphyromonas                   Actinomyces
#                   0.023252443                   0.019339913
#                Pseudonocardia                 Streptococcus
#                   0.019240122                   0.018125725
#                     Atopobium                Granulicatella
#                   0.015254918                   0.014123629
#                   Veillonella     TM7_genera_incertae_sedis
#                   0.013919140                   0.013888007
#                     Treponema                   Selenomonas
#                   0.013837861                   0.013693598
#                    Prevotella                       Gemella
#                   0.013328394                   0.013181618
#                 Lactobacillus                 Fusobacterium
#                   0.012854344                   0.012552865
#     OD1_genera_incertae_sedis                     Catonella
#                   0.012533430                   0.012345472
#                Capnocytophaga                 Campylobacter
#                   0.011600300                   0.011150224
#                    Parvimonas                     Neisseria
#                   0.010869983                   0.010152069
#                Staphylococcus               Corynebacterium

# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 7th repetition"
# [1] "Load data for repetition 7"
#                        Rothia                  Oribacterium
#                   0.337638993                   0.090726283
#             Propionibacterium                    Tropheryma
#                   0.063729222                   0.031841612
#                      Moryella                       Gemella
#                   0.026821160                   0.023405899
#                Pseudonocardia                    Prevotella
#                   0.022999904                   0.021541407
#                    Filifactor                   Veillonella
#                   0.020399378                   0.019148752
#     TM7_genera_incertae_sedis                 Fusobacterium
#                   0.018168372                   0.018132933
#                 Porphyromonas                 Streptococcus
#                   0.017499527                   0.015997128
#                   Selenomonas                   Actinomyces
#                   0.015223830                   0.015093220
#                Capnocytophaga                    Parvimonas
#                   0.014676638                   0.014218891
#                     Treponema                 Campylobacter
#                   0.013664620                   0.013249485
#     OD1_genera_incertae_sedis                     Catonella
#                   0.012777207                   0.012370804
#               Corynebacterium                Granulicatella
#                   0.011061499                   0.010838488
#                 Lactobacillus                   Megasphaera
#                   0.010644059                   0.009887043
#                     Neisseria                     Atopobium
#                   0.009430173                   0.009103678
#                Staphylococcus                      Sneathia
#                   0.008693074                   0.008691731
#                 Solobacterium                Flavobacterium
#                   0.007685127                   0.007253336
#                   Haemophilus                  Burkholderia
#                   0.007204962                   0.006956868
#                  Sphingomonas              Methylobacterium
#                   0.006668977                   0.005641485
#                  Bdellovibrio                     Moraxella
#                   0.005079738                   0.004594328
#                     Rhizobium              Chryseobacterium
#                   0.004387445                   0.004299302
#                Fastidiosipila                    Finegoldia
#                   0.003896864                   0.003829477
#                Microbacterium Lachnospiracea_incertae_sedis
#                   0.003753698                   0.003574805
#                   Bacteroides                  Streptophyta
#                   0.002586173                   0.001960162
#                    Paracoccus                Bradyrhizobium
#                   0.001496814                   0.001455426
# [1] "Train sensitivity: 0.780487804878049, Train sensitivity: 0.954128440366973, Train gmeasure: 0.862951685781849, Train accuracy: 0.906666666666667, Train AUC: 0.867308122622511"
# [1] "Test sensitivity: 0.775, Test sensitivity: 0.970588235294118, Test gmeasure: 0.867298035483156, Test accuracy: 0.908, Test AUC: 0.872794117647059"
# [1] "FS sensitivity: 1, FS sensitivity: 0.0526315789473684, FS gmeasure: 0.229415733870562, FS accuracy: 0.625"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 8th repetition"
# [1] "Load data for repetition 8"
#                        Rothia                  Oribacterium
#                   0.328665995                   0.114098853
#             Propionibacterium                      Moryella
#                   0.050318514                   0.037215582
#                    Tropheryma                   Actinomyces
#                   0.033043985                   0.023551368
#                Pseudonocardia                 Streptococcus
#                   0.020955919                   0.019593290
#                    Filifactor                 Fusobacterium
#                   0.019302873                   0.018042784
#                 Porphyromonas                     Treponema
#                   0.016575529                   0.016560745
#                    Prevotella     TM7_genera_incertae_sedis
#                   0.014662247                   0.014505480
#                 Campylobacter                   Megasphaera
#                   0.013561617                   0.013292454
#                       Gemella                     Catonella
#                   0.013221466                   0.012952270
#                   Selenomonas                    Parvimonas
#                   0.012951111                   0.012685486
#                   Veillonella                Capnocytophaga
#                   0.012624974                   0.012465244
#                 Lactobacillus     OD1_genera_incertae_sedis
#                   0.012040864                   0.011936572
#                Granulicatella                     Neisseria
#                   0.011357647                   0.010738412
#               Corynebacterium                Staphylococcus
#                   0.010406557                   0.009690148
#                Flavobacterium                     Atopobium
#                   0.009631945                   0.009381117
#                 Solobacterium                   Haemophilus
#                   0.008964810                   0.008556326
#              Methylobacterium Lachnospiracea_incertae_sedis
#                   0.008142840                   0.007266965
#                      Sneathia                  Burkholderia
#                   0.006838139                   0.006798237
#                  Sphingomonas                Fastidiosipila
#                   0.005469672                   0.004522465
#                  Streptophyta              Chryseobacterium
#                   0.004478081                   0.004475036
#                  Bdellovibrio                   Bacteroides
#                   0.003778850                   0.002951793
#                     Moraxella                Microbacterium
#                   0.002856607                   0.002782475
#                     Rhizobium                    Paracoccus
#                   0.002035520                   0.001433046
#                    Finegoldia                Bradyrhizobium
#                   0.001341622                   0.001276468
# [1] "Train sensitivity: 0.79047619047619, Train sensitivity: 0.97037037037037, Train gmeasure: 0.875816575386274, Train accuracy: 0.92, Train AUC: 0.88042328042328"
# [1] "Test sensitivity: 0.8, Test sensitivity: 0.966666666666667, Test gmeasure: 0.879393730551528, Test accuracy: 0.92, Test AUC: 0.883333333333333"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 9th repetition"
# [1] "Load data for repetition 9"
#                        Rothia             Propionibacterium
#                   0.273454403                   0.090019117
#                  Oribacterium                    Tropheryma
#                   0.079656085                   0.054857758
#                    Filifactor                Pseudonocardia
#                   0.034445122                   0.029999082
#                      Moryella                   Actinomyces
#                   0.029110642                   0.028239321
#                 Porphyromonas                Granulicatella
#                   0.022924147                   0.019081991
#                 Fusobacterium     TM7_genera_incertae_sedis
#                   0.016931460                   0.016780155
#                    Prevotella                       Gemella
#                   0.015770524                   0.014957588
#                Capnocytophaga                 Streptococcus
#                   0.014211862                   0.013745188
#                 Lactobacillus                   Selenomonas
#                   0.013741536                   0.013219811
#                     Treponema                   Veillonella
#                   0.013106251                   0.012801554
#                     Catonella     OD1_genera_incertae_sedis
#                   0.012642014                   0.012201624
#               Corynebacterium                 Campylobacter
#                   0.012129401                   0.011677136
#                     Neisseria                    Parvimonas
#                   0.010634483                   0.010552442
#                      Sneathia                     Atopobium
#                   0.009983040                   0.009940403
#                Flavobacterium                  Sphingomonas
#                   0.009632048                   0.009225927
#                   Haemophilus                   Megasphaera
#                   0.009217851                   0.008071315
#                  Burkholderia                Staphylococcus
#                   0.008046557                   0.007426996
#                 Solobacterium              Methylobacterium
#                   0.006527542                   0.005487925
# Lachnospiracea_incertae_sedis                   Bacteroides
#                   0.005046275                   0.004623196
#                  Bdellovibrio                Microbacterium
#                   0.004608717                   0.004042648
#              Chryseobacterium                     Moraxella
#                   0.003215562                   0.003075612
#                    Paracoccus                  Streptophyta
#                   0.003011908                   0.002800550
#                Bradyrhizobium                    Finegoldia
#                   0.002780922                   0.002218169
#                     Rhizobium                Fastidiosipila
#                   0.002176729                   0.001949414
# [1] "Train sensitivity: 0.798245614035088, Train sensitivity: 0.959770114942529, Train gmeasure: 0.875289828990847, Train accuracy: 0.910666666666667, Train AUC: 0.879007864488808"
# [1] "Test sensitivity: 0.866666666666667, Test sensitivity: 0.971428571428571, Test gmeasure: 0.917553683391202, Test accuracy: 0.94, Test AUC: 0.919047619047619"
# [1] "FS sensitivity: 1, FS sensitivity: 0.0526315789473684, FS gmeasure: 0.229415733870562, FS accuracy: 0.625"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 10th repetition"
# [1] "Load data for repetition 10"
#                        Rothia                  Oribacterium
#                  0.3410348233                  0.1094109299
#             Propionibacterium                    Tropheryma
#                  0.0513478596                  0.0360484772
#                      Moryella                    Filifactor
#                  0.0340583562                  0.0315620957
#                   Actinomyces     TM7_genera_incertae_sedis
#                  0.0188049787                  0.0174592910
#                 Streptococcus                     Catonella
#                  0.0168634984                  0.0153325361
#                    Prevotella                Pseudonocardia
#                  0.0144009573                  0.0138797213
#     OD1_genera_incertae_sedis                Granulicatella
#                  0.0137176616                  0.0135852672
#                 Campylobacter                 Porphyromonas
#                  0.0130995397                  0.0130920036
#                   Selenomonas                 Lactobacillus
#                  0.0130195896                  0.0130145773
#                   Veillonella                Capnocytophaga
#                  0.0128798412                  0.0127628628
#                 Fusobacterium                   Megasphaera
#                  0.0127029588                  0.0115453416
#                 Solobacterium                    Parvimonas
#                  0.0109692508                  0.0106739218
#               Corynebacterium                     Treponema
#                  0.0106726350                  0.0105690053
#                       Gemella                     Neisseria
#                  0.0105543197                  0.0103635698
#                Staphylococcus                     Atopobium
#                  0.0098631781                  0.0085922750
#                   Haemophilus                  Burkholderia
#                  0.0081711475                  0.0078588972
#                  Sphingomonas                      Sneathia
#                  0.0076779996                  0.0072419764
# Lachnospiracea_incertae_sedis              Methylobacterium
#                  0.0065558292                  0.0065274067
#                Fastidiosipila                Flavobacterium
#                  0.0063024844                  0.0059976664
#              Chryseobacterium                Microbacterium
#                  0.0051510404                  0.0049901033
#                  Bdellovibrio                  Streptophyta
#                  0.0045681519                  0.0041412831
#                     Rhizobium                   Bacteroides
#                  0.0037294541                  0.0029536364
#                     Moraxella                    Paracoccus
#                  0.0022262440                  0.0016054268
#                    Finegoldia                Bradyrhizobium
#                  0.0014646616                  0.0009552676
# [1] "Train sensitivity: 0.824786324786325, Train sensitivity: 0.959302325581395, Train gmeasure: 0.889505165513531, Train accuracy: 0.917333333333333, Train AUC: 0.89204432518386"
# [1] "Test sensitivity: 0.808988764044944, Test sensitivity: 0.968944099378882, Test gmeasure: 0.885361445617078, Test accuracy: 0.912, Test AUC: 0.888966431711913"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"

# %%
results_table = res %>% t %>% data.frame
colnames(results_table) = c('Train sensitivity', 'Train sensitivity', 'Train gmeasure', 'Train accuracy', 'Train AUC',
                            'Test sensitivity', 'Test sensitivity', 'Test gmeasure', 'Test accuracy', 'Test AUC',
                            'Taxa selection sensitivity','Taxa selection sensitivity',
                            'Taxa selection gmeasure', 'Taxa selection accuracy')
results_table
# Out:
#    Train sensitivity Train sensitivity Train gmeasure Train accuracy Train AUC
# 1  0.7801724         0.9710425         0.8703910      0.9120000      0.8756074
# 2  0.7156863         0.9743590         0.8350661      0.9040000      0.8450226
# 3  0.7698745         0.9549902         0.8574512      0.8960000      0.8624323
# 4  0.8045455         0.9716981         0.8841806      0.9226667      0.8881218
# 5  0.7545455         0.9698113         0.8554336      0.9066667      0.8621784
# 6  0.7822222         0.9733333         0.8725612      0.9160000      0.8777778
# 7  0.7804878         0.9541284         0.8629517      0.9066667      0.8673081
# 8  0.7904762         0.9703704         0.8758166      0.9200000      0.8804233
# 9  0.7982456         0.9597701         0.8752898      0.9106667      0.8790079
# 10 0.8247863         0.9593023         0.8895052      0.9173333      0.8920443
#    Test sensitivity Test sensitivity Test gmeasure Test accuracy Test AUC
# 1  0.8395062        0.9881657        0.9108080     0.940         0.9138359
# 2  0.7236842        0.9827586        0.8433308     0.904         0.8532214
# 3  0.7916667        0.9719101        0.8771709     0.920         0.8817884
# 4  0.8607595        0.9707602        0.9141067     0.936         0.9157599
# 5  0.7733333        0.9714286        0.8667399     0.912         0.8723810
# 6  0.7972973        0.9772727        0.8827100     0.924         0.8872850
# 7  0.7750000        0.9705882        0.8672980     0.908         0.8727941
# 8  0.8000000        0.9666667        0.8793937     0.920         0.8833333
# 9  0.8666667        0.9714286        0.9175537     0.940         0.9190476
# 10 0.8089888        0.9689441        0.8853614     0.912         0.8889664
#    Taxa selection sensitivity Taxa selection sensitivity
# 1  1                          0.10526316
# 2  1                          0.10526316
# 3  1                          0.10526316
# 4  1                          0.10526316
# 5  1                          0.10526316
# 6  1                          0.10526316
# 7  1                          0.05263158
# 8  1                          0.10526316
# 9  1                          0.05263158
# 10 1                          0.10526316
#    Taxa selection gmeasure Taxa selection accuracy
# 1  0.3244428               0.6458333
# 2  0.3244428               0.6458333
# 3  0.3244428               0.6458333
# 4  0.3244428               0.6458333
# 5  0.3244428               0.6458333
# 6  0.3244428               0.6458333
# 7  0.2294157               0.6250000
# 8  0.3244428               0.6458333
# 9  0.2294157               0.6250000
# 10 0.3244428               0.6458333

# %%
print('Mean')
apply(results_table, 2, mean)
# Out:
# [1] "Mean"
#          Train sensitivity          Train sensitivity
#                 0.78010422                 0.96588057
#             Train gmeasure             Train accuracy
#                 0.86786470                 0.91120000
#                  Train AUC           Test sensitivity
#                 0.87299240                 0.80369026
#           Test sensitivity              Test gmeasure
#                 0.97399235                 0.88444733
#              Test accuracy                   Test AUC
#                 0.92160000                 0.88884131
# Taxa selection sensitivity Taxa selection sensitivity
#                 1.00000000                 0.09473684
#    Taxa selection gmeasure    Taxa selection accuracy
#                 0.30543742                 0.64166667

# %%
print('SD')
apply(results_table, 2, sd)
# Out:
# [1] "SD"
#          Train sensitivity          Train sensitivity
#                0.029707388                0.007894080
#             Train gmeasure             Train accuracy
#                0.015790929                0.008127381
#                  Train AUC           Test sensitivity
#                0.013968588                0.043305729
#           Test sensitivity              Test gmeasure
#                0.006726055                0.023690480
#              Test accuracy                   Test AUC
#                0.013226237                0.021451528
# Taxa selection sensitivity Taxa selection sensitivity
#                0.000000000                0.022191422
#    Taxa selection gmeasure    Taxa selection accuracy
#                0.040066947                0.008784105
