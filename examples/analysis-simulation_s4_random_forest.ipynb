# %% [markdown]
# # Scenario 4. Robustness (regression design)
#
# ## Strategy 1. Measurement errors (Table 10)

# %%
R.version
library(tidyverse)
library(caret)
library(randomForest)
library(reticulate)
np <- import("numpy")
# Out:
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          3
# minor          5.3
# year           2019
# month          03
# day            11
# svn rev        76217
# language       R
# version.string R version 3.5.3 (2019-03-11)
# nickname       Great Truth
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
#
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin

# %% [markdown]
# ### Configuration

# %%
data_path = "./data/simulation/s4"
path_genus = "./data/genus48"

y_path = sprintf('%s/%s', data_path, 'y.csv')
tree_info_path = './data/genus48/genus48_dic.csv'
count_path = './data/simulation/count_me'
count_list_path = './data/simulation/gcount_list.csv'
idx_path = './data/simulation/s1/idx.csv'

num_classes = 0 # regression
tree_level_list = c('Genus', 'Family', 'Order', 'Class', 'Phylum')

# %%
# # Read phylogenetic tree information

# phylogenetic_tree_info = read.csv(tree_info_path)
# phylogenetic_tree_info = phylogenetic_tree_info %>% select(tree_level_list)

# print(sprintf('Phylogenetic tree level list: %s', str_c(phylogenetic_tree_info %>% colnames, collapse = ', ')))

# %% [markdown]
# ### Read dataset

# %% [markdown]
# #### Read training, test dataset

# %%
read_dataset <- function(x_path, y_path, sim){
    print(str_c('Load data for repetition ', sim))
    x = read.csv(x_path)
    y = read.csv(y_path)[,sim]
    x = (x - max(x)) / (max(x) - min(x))

    idxs = idxs_total[, sim]
    remain_idxs = setdiff(seq(1, dim(x)[1]), idxs)

    x_train = x[idxs,]
    x_test = x[remain_idxs,]
    y_train = y[idxs]
    y_test = y[remain_idxs]
    
    return (list(x_train, x_test, y_train, y_test))
}

# %%
idxs_total = read.csv(idx_path)
number_of_fold = dim(idxs_total)[2]; number_of_fold
x_list = read.csv(count_list_path, header = FALSE)
x_path = x_list$V1 %>% sprintf('%s/%s', count_path, .)
# Out:
# [1] 1000

# %% [markdown]
# #### Read true tree weight

# %%
tw_1 = np$load(sprintf('%s/tw_1.npy', data_path))

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Importance type
#
# * See <https://stats.stackexchange.com/questions/92419/relative-importance-of-a-set-of-predictors-in-a-random-forests-classification-in>
#
# Here are the definitions of the variable importance measures.
#
# - `type=1`: **Mean decrease in accuracy**
#     - The first measure is computed from permuting Out-of-bag (OOB) data.
#     - For each tree, the prediction error on the out-of-bag portion of the data is recorded (error rate for classification, MSE for regression). Then the same is done after permuting each predictor variable.
#     - The difference between the two are then averaged over all trees, and normalized by the standard deviation of the differences.
#     - If the standard deviation of the differences is equal to 0 for a variable, the division is not done (but the average is almost always equal to 0 in that case).
#
# - `type=2`: **Mean decrease in node impurity**
#     - The second measure is the total decrease in node impurities from splitting on the variable, averaged over all trees.
#     - For classification, the node impurity is measured by the Gini index.
#     - For regression, it is measured by residual sum of squares.
#
# ### Feature selection
#
# * `vi_f`: variable importance by Gini importance (`type=2`)
# * `relative_vi_f` : relative variable importance
# * `thrd`: threshold for relative variable importance
# * Select features which have relative variable importance `relative_vi_f` equal or larger than threshold `thrd`

# %% [markdown]
# ### Simulate for all $n$

# %%
random_forest_res <- function(fold, importance_type=2, fs_thrd = 0.1){
    print(sprintf('-----------------------------------------------------------------'))
    print(sprintf('Random Forest computation for %dth repetition', fold))

    dataset = read_dataset(x_path[fold], y_path, fold)
    x_train = dataset[[1]]
    x_test = dataset[[2]]
    y_train = dataset[[3]]
    y_test = dataset[[4]]

    fit.rf <- randomForest(y_train~.,data=x_train, ntree=1000,  mtry=10, importance=TRUE)
    train.pred <- fit.rf$predicted
    test.pred <- predict(fit.rf,x_test)

    train.mse <- mean((y_train - train.pred)^2)
    train.cor <- cor(y_train, train.pred)

    test.mse <- mean((y_test - test.pred)^2)
    test.cor <- cor(y_test, test.pred)
    
    # Feature selection
    ## variable importance
    vi_f = importance(fit.rf, type=importance_type)
    relative_vi_f <- vi_f / sum(vi_f)
    selected_genus <- ifelse(relative_vi_f >= fs_thrd, 1, 0)
    
    order <- order(relative_vi_f, decreasing = TRUE)
    sorted_relative_vi_f <- relative_vi_f[order]
    names(sorted_relative_vi_f) <- colnames(x_train)[order]
    print(sorted_relative_vi_f)

    fold_genus = apply(tw_1[fold,,], 1, sum)
    names(fold_genus) <- x_train %>% colnames

    fs_conf_table <- table(selected_genus, fold_genus)
    
    fs_sensitivity <- sensitivity(fs_conf_table) 
    fs_specificity <- specificity(fs_conf_table)
    fs_gmeasure <- sqrt(fs_sensitivity*fs_specificity)
    fs_accuracy <- sum(diag(fs_conf_table))/sum(fs_conf_table)

    print(sprintf('Train mse: %s, Train Correlation: %s', train.mse, train.cor))
    print(sprintf('Test mse: %s, Test Correlation: %s', test.mse, test.cor))
    print(sprintf('FS sensitivity: %s, FS sensitivity: %s, FS gmeasure: %s, FS accuracy: %s',
                  fs_sensitivity, fs_specificity, fs_gmeasure, fs_accuracy))
    
    return (c(train.mse, train.cor, test.mse, test.cor, fs_sensitivity, fs_specificity, fs_gmeasure, fs_accuracy))
}

# %%
set.seed(100)
# res <- sapply(seq(1,1), random_forest_res)
res <- sapply(seq(1,10), random_forest_res)
# res <- sapply(seq(1,number_of_fold), random_forest_res)
# Out:
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 1th repetition"
# [1] "Load data for repetition 1"
#                        Rothia                    Tropheryma
#                  0.2909319254                  0.1856261357
#                   Actinomyces             Propionibacterium
#                  0.0702610616                  0.0620667479
#                Pseudonocardia               Corynebacterium
#                  0.0358253198                  0.0247893868
#                     Atopobium     TM7_genera_incertae_sedis
#                  0.0180489952                  0.0164813458
#                 Streptococcus                    Prevotella
#                  0.0135711852                  0.0131422695
#                Capnocytophaga                  Oribacterium
#                  0.0128482667                  0.0120665964
#                   Selenomonas                     Treponema
#                  0.0116877910                  0.0116615931
#                 Fusobacterium                 Solobacterium
#                  0.0114654966                  0.0110765531
#                 Lactobacillus                    Parvimonas
#                  0.0109469930                  0.0109144831
#                Granulicatella                   Veillonella
#                  0.0106532440                  0.0101285702
#                       Gemella                     Catonella
#                  0.0100815006                  0.0097940798
#                 Campylobacter                 Porphyromonas
#                  0.0097714330                  0.0094962370
#                Microbacterium                   Bacteroides
#                  0.0093851696                  0.0092579420
#     OD1_genera_incertae_sedis                    Filifactor
#                  0.0090360149                  0.0089544492
#                      Moryella                   Megasphaera
#                  0.0082405643                  0.0073618495
#                Flavobacterium                     Neisseria
#                  0.0073245903                  0.0068227822
#                Staphylococcus                   Haemophilus
#                  0.0065636208                  0.0063282885
#                      Sneathia                  Burkholderia
#                  0.0060803596                  0.0051310759
#                  Sphingomonas              Methylobacterium
#                  0.0049259360                  0.0039054311
#              Chryseobacterium                  Bdellovibrio
#                  0.0035531508                  0.0029695482
#                     Moraxella                     Rhizobium
#                  0.0018637683                  0.0017385290
#                Bradyrhizobium                  Streptophyta
#                  0.0017040744                  0.0014710185
#                    Paracoccus                Fastidiosipila
#                  0.0014420593                  0.0009585052
#                    Finegoldia Lachnospiracea_incertae_sedis
#                  0.0008853237                  0.0007587383
# [1] "Train mse: 0.71031458184196, Train Correlation: 0.904886915325663"
# [1] "Test mse: 0.824867026231258, Test Correlation: 0.891250565072948"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 2th repetition"
# [1] "Load data for repetition 2"
#                        Rothia                    Tropheryma
#                  0.2703535425                  0.1874018270
#             Propionibacterium                   Actinomyces
#                  0.0721730172                  0.0493863872
#               Corynebacterium                Pseudonocardia
#                  0.0350379301                  0.0321817099
#                Capnocytophaga                     Atopobium
#                  0.0179378677                  0.0145046199
#                    Prevotella                Granulicatella
#                  0.0139410476                  0.0136780449
#                 Fusobacterium                     Catonella
#                  0.0122739708                  0.0121948523
#                   Veillonella                   Selenomonas
#                  0.0120692366                  0.0118325644
#     TM7_genera_incertae_sedis                     Treponema
#                  0.0117970867                  0.0114585782
#                       Gemella                 Streptococcus
#                  0.0112467051                  0.0109940217
#                 Solobacterium                 Lactobacillus
#                  0.0105338181                  0.0102286469
#                    Parvimonas                 Porphyromonas
#                  0.0101666303                  0.0100047876
#                 Campylobacter                   Bacteroides
#                  0.0099968690                  0.0098980932
#                    Filifactor     OD1_genera_incertae_sedis
#                  0.0098819770                  0.0098623089
#                Staphylococcus                      Moryella
#                  0.0089929497                  0.0089742794
#                     Neisseria                   Megasphaera
#                  0.0086557541                  0.0084982119
#                Microbacterium                Flavobacterium
#                  0.0080388388                  0.0078119334
#                  Oribacterium                  Burkholderia
#                  0.0078109164                  0.0068880689
#                   Haemophilus                      Sneathia
#                  0.0063953663                  0.0062433131
#                  Sphingomonas                     Moraxella
#                  0.0060604931                  0.0045671576
#              Methylobacterium                Bradyrhizobium
#                  0.0042666675                  0.0041092947
#                    Paracoccus              Chryseobacterium
#                  0.0038948764                  0.0038386229
#                  Bdellovibrio                     Rhizobium
#                  0.0038021687                  0.0037309526
#                  Streptophyta                    Finegoldia
#                  0.0031291739                  0.0014373326
# Lachnospiracea_incertae_sedis                Fastidiosipila
#                  0.0010019022                  0.0008155851
# [1] "Train mse: 0.768706425714328, Train Correlation: 0.887222975010603"
# [1] "Test mse: 0.711473549602997, Test Correlation: 0.921904778330742"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 3th repetition"
# [1] "Load data for repetition 3"
#                        Rothia                    Tropheryma
#                  0.2424390002                  0.2200458562
#                   Actinomyces             Propionibacterium
#                  0.0714000191                  0.0527161537
#                Pseudonocardia               Corynebacterium
#                  0.0407600162                  0.0381045125
#     TM7_genera_incertae_sedis                     Atopobium
#                  0.0166032858                  0.0165537532
#                Microbacterium                    Prevotella
#                  0.0160444503                  0.0147631618
#                   Selenomonas                      Sneathia
#                  0.0121033410                  0.0120151114
#                 Lactobacillus                 Campylobacter
#                  0.0117212649                  0.0114404869
#                Capnocytophaga                    Parvimonas
#                  0.0113809330                  0.0113667106
#                   Veillonella                 Fusobacterium
#                  0.0111589334                  0.0110040264
#                 Solobacterium                 Streptococcus
#                  0.0104129639                  0.0103960899
#                       Gemella                     Treponema
#                  0.0102666309                  0.0100031209
#                   Bacteroides                      Moryella
#                  0.0097454909                  0.0097336025
#                 Porphyromonas                Granulicatella
#                  0.0093930578                  0.0092826796
#                     Catonella                Staphylococcus
#                  0.0088722087                  0.0083454345
#                     Neisseria     OD1_genera_incertae_sedis
#                  0.0082637608                  0.0080105670
#                    Filifactor                  Oribacterium
#                  0.0075386437                  0.0072617508
#                   Megasphaera                   Haemophilus
#                  0.0072255879                  0.0063412462
#                Flavobacterium                  Burkholderia
#                  0.0055703210                  0.0053857248
#                  Sphingomonas              Methylobacterium
#                  0.0044328929                  0.0042760204
#                  Bdellovibrio              Chryseobacterium
#                  0.0032810347                  0.0029099042
#                     Rhizobium                     Moraxella
#                  0.0023009028                  0.0018468340
#                    Finegoldia                  Streptophyta
#                  0.0015133654                  0.0014996750
# Lachnospiracea_incertae_sedis                Bradyrhizobium
#                  0.0012567839                  0.0012017649
#                    Paracoccus                Fastidiosipila
#                  0.0009677234                  0.0008432000
# [1] "Train mse: 0.732864850102182, Train Correlation: 0.902266687710846"
# [1] "Test mse: 0.798095550289007, Test Correlation: 0.867122733675279"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 4th repetition"
# [1] "Load data for repetition 4"
#                        Rothia                    Tropheryma
#                  0.2792885360                  0.1687074590
#             Propionibacterium                   Actinomyces
#                  0.0705408306                  0.0579396584
#                Pseudonocardia               Corynebacterium
#                  0.0342777705                  0.0263237505
#                Capnocytophaga                     Atopobium
#                  0.0176954985                  0.0173092851
#                 Streptococcus                 Campylobacter
#                  0.0140784810                  0.0137492100
#                    Prevotella                       Gemella
#                  0.0137291339                  0.0136034013
#                 Lactobacillus                      Moryella
#                  0.0134221391                  0.0129719611
#                   Bacteroides                     Catonella
#                  0.0126020885                  0.0125238913
#                 Fusobacterium                     Treponema
#                  0.0123627248                  0.0122122348
#                Microbacterium                   Selenomonas
#                  0.0117171780                  0.0115845680
#                Granulicatella                 Porphyromonas
#                  0.0115392408                  0.0114571479
#                   Veillonella                    Parvimonas
#                  0.0113323066                  0.0110467435
#     TM7_genera_incertae_sedis                 Solobacterium
#                  0.0104267191                  0.0103116792
#     OD1_genera_incertae_sedis                     Neisseria
#                  0.0101588855                  0.0087503281
#                Staphylococcus                    Filifactor
#                  0.0082585925                  0.0082503590
#                   Megasphaera                  Oribacterium
#                  0.0080239635                  0.0078948443
#                Flavobacterium                      Sneathia
#                  0.0071888719                  0.0067480107
#                  Burkholderia                   Haemophilus
#                  0.0065330645                  0.0064317126
#                  Bdellovibrio                  Sphingomonas
#                  0.0046271178                  0.0045744898
#              Methylobacterium                     Moraxella
#                  0.0044983681                  0.0035383957
#              Chryseobacterium                Fastidiosipila
#                  0.0034165726                  0.0015724775
#                     Rhizobium                Bradyrhizobium
#                  0.0013223421                  0.0013051009
#                  Streptophyta                    Finegoldia
#                  0.0011566781                  0.0011106305
# Lachnospiracea_incertae_sedis                    Paracoccus
#                  0.0010612615                  0.0008242953
# [1] "Train mse: 0.813272714726216, Train Correlation: 0.884581662851287"
# [1] "Test mse: 0.662330129410926, Test Correlation: 0.889151155131704"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 5th repetition"
# [1] "Load data for repetition 5"
#                        Rothia                    Tropheryma
#                   0.281789427                   0.179980834
#             Propionibacterium                   Actinomyces
#                   0.064384222                   0.058259352
#                Pseudonocardia               Corynebacterium
#                   0.042949001                   0.037734258
#                     Atopobium                     Treponema
#                   0.017784046                   0.012138721
#                       Gemella                   Selenomonas
#                   0.012020419                   0.011769712
#                    Prevotella     TM7_genera_incertae_sedis
#                   0.011703857                   0.011548305
#                Capnocytophaga                      Moryella
#                   0.011342578                   0.011339885
#                 Streptococcus                   Bacteroides
#                   0.011329736                   0.010982707
#                 Fusobacterium                 Lactobacillus
#                   0.010932004                   0.010870815
#                Granulicatella                 Porphyromonas
#                   0.010595932                   0.010251321
#     OD1_genera_incertae_sedis                   Veillonella
#                   0.010193154                   0.010180762
#                    Parvimonas                 Solobacterium
#                   0.010166701                   0.009983681
#                     Catonella                 Campylobacter
#                   0.009836796                   0.009818310
#                    Filifactor                     Neisseria
#                   0.008798923                   0.008714180
#                Staphylococcus                   Megasphaera
#                   0.008631792                   0.008421513
#                  Sphingomonas                Microbacterium
#                   0.008001321                   0.007996840
#                  Oribacterium                      Sneathia
#                   0.007727295                   0.006831122
#                   Haemophilus                  Burkholderia
#                   0.005469333                   0.005165240
#                Flavobacterium              Methylobacterium
#                   0.005107696                   0.004744118
#                  Bdellovibrio                     Rhizobium
#                   0.004454860                   0.003529042
#              Chryseobacterium                     Moraxella
#                   0.003310660                   0.002971174
#                  Streptophyta                Bradyrhizobium
#                   0.002544098                   0.002407006
# Lachnospiracea_incertae_sedis                    Finegoldia
#                   0.001593665                   0.001300002
#                    Paracoccus                Fastidiosipila
#                   0.001292255                   0.001101330
# [1] "Train mse: 0.769798849610571, Train Correlation: 0.902304609909424"
# [1] "Test mse: 0.84993413386828, Test Correlation: 0.890446831957596"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 6th repetition"
# [1] "Load data for repetition 6"
#                        Rothia                    Tropheryma
#                   0.324382187                   0.175648037
#                   Actinomyces             Propionibacterium
#                   0.068596997                   0.054320776
#               Corynebacterium                Pseudonocardia
#                   0.030543247                   0.024636375
#                 Streptococcus                     Atopobium
#                   0.015317529                   0.015277700
#                    Prevotella                Capnocytophaga
#                   0.014745561                   0.012167752
#                Granulicatella                 Fusobacterium
#                   0.011958046                   0.011736146
#                 Campylobacter                   Veillonella
#                   0.011723191                   0.011521038
#                       Gemella                 Lactobacillus
#                   0.011298007                   0.011261463
#     TM7_genera_incertae_sedis                     Treponema
#                   0.011032822                   0.010208610
#                   Bacteroides                   Selenomonas
#                   0.009986342                   0.009965370
#                    Parvimonas                      Moryella
#                   0.009791814                   0.009593539
#                Staphylococcus                 Porphyromonas
#                   0.009358850                   0.008913833
#                 Solobacterium                Microbacterium
#                   0.008842257                   0.008550977
#                     Catonella                     Neisseria
#                   0.008440185                   0.008156011
#     OD1_genera_incertae_sedis                    Filifactor
#                   0.008146590                   0.007862463
#                  Oribacterium                   Megasphaera
#                   0.006719568                   0.006638562
#                  Burkholderia                      Sneathia
#                   0.006218165                   0.006016352
#                   Haemophilus              Methylobacterium
#                   0.005818228                   0.005590566
#                Flavobacterium                  Sphingomonas
#                   0.005482283                   0.005316424
#              Chryseobacterium                     Moraxella
#                   0.003432818                   0.002604293
#                  Bdellovibrio                  Streptophyta
#                   0.002361396                   0.001961690
#                Bradyrhizobium                     Rhizobium
#                   0.001938737                   0.001599941
# Lachnospiracea_incertae_sedis                    Paracoccus
#                   0.001220195                   0.001062227
#                    Finegoldia                Fastidiosipila
#                   0.001018309                   0.001016531
# [1] "Train mse: 0.688530904611375, Train Correlation: 0.90596983337213"
# [1] "Test mse: 0.758892803960356, Test Correlation: 0.883791323186394"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 7th repetition"
# [1] "Load data for repetition 7"
#                        Rothia                    Tropheryma
#                  0.2853559373                  0.1817852832
#                   Actinomyces             Propionibacterium
#                  0.0666984040                  0.0564439010
#                Pseudonocardia               Corynebacterium
#                  0.0384043907                  0.0353723071
#                     Atopobium                       Gemella
#                  0.0185183689                  0.0172883742
#                 Streptococcus                 Lactobacillus
#                  0.0168813051                  0.0129069533
#                 Porphyromonas                 Fusobacterium
#                  0.0124582519                  0.0122800944
#                 Solobacterium                 Campylobacter
#                  0.0119217308                  0.0118987248
#                Capnocytophaga     TM7_genera_incertae_sedis
#                  0.0117690583                  0.0117460755
#                Granulicatella                    Prevotella
#                  0.0116131160                  0.0111903433
#                     Treponema                    Parvimonas
#                  0.0110393366                  0.0106774066
#                   Veillonella                   Selenomonas
#                  0.0102852465                  0.0101268234
#                     Catonella                   Bacteroides
#                  0.0094434039                  0.0094298550
#                      Moryella                      Sneathia
#                  0.0091021387                  0.0088606086
#     OD1_genera_incertae_sedis                Microbacterium
#                  0.0085299477                  0.0072850378
#                    Filifactor                Flavobacterium
#                  0.0070832558                  0.0070323346
#                Staphylococcus                     Neisseria
#                  0.0067337872                  0.0066424527
#                   Megasphaera                  Oribacterium
#                  0.0066155839                  0.0065303858
#                   Haemophilus                  Burkholderia
#                  0.0057895435                  0.0054130293
#                  Sphingomonas              Methylobacterium
#                  0.0051365091                  0.0048506910
#              Chryseobacterium                  Bdellovibrio
#                  0.0032921055                  0.0027664717
#                  Streptophyta                     Moraxella
#                  0.0025507367                  0.0019914578
#                Fastidiosipila                Bradyrhizobium
#                  0.0019720629                  0.0017402888
#                     Rhizobium                    Finegoldia
#                  0.0016731326                  0.0013256017
# Lachnospiracea_incertae_sedis                    Paracoccus
#                  0.0008897345                  0.0006584100
# [1] "Train mse: 0.72849092759872, Train Correlation: 0.895850042393213"
# [1] "Test mse: 0.765218674668713, Test Correlation: 0.88250658769753"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 8th repetition"
# [1] "Load data for repetition 8"
#                        Rothia                    Tropheryma
#                  0.2959709294                  0.1918528180
#             Propionibacterium                   Actinomyces
#                  0.0530659544                  0.0501730649
#                Pseudonocardia               Corynebacterium
#                  0.0375528640                  0.0260878083
#                     Atopobium                 Streptococcus
#                  0.0169877199                  0.0154013897
#                    Prevotella                     Treponema
#                  0.0148632198                  0.0138194580
#                   Selenomonas                 Fusobacterium
#                  0.0116230515                  0.0115848136
#                       Gemella                Capnocytophaga
#                  0.0114419752                  0.0110281718
#                Granulicatella                   Veillonella
#                  0.0108693240                  0.0108479425
#                 Porphyromonas                   Bacteroides
#                  0.0107954953                  0.0107442188
#     TM7_genera_incertae_sedis                 Lactobacillus
#                  0.0107430080                  0.0107095123
#                 Campylobacter                 Solobacterium
#                  0.0105181492                  0.0101513619
#                      Moryella                Microbacterium
#                  0.0101363309                  0.0094333393
#                    Parvimonas     OD1_genera_incertae_sedis
#                  0.0091980820                  0.0091699034
#                     Catonella                   Megasphaera
#                  0.0089436479                  0.0085770488
#                    Filifactor                Staphylococcus
#                  0.0085671497                  0.0081773707
#                     Neisseria                  Sphingomonas
#                  0.0080328910                  0.0079687298
#                  Oribacterium                   Haemophilus
#                  0.0069067112                  0.0069040991
#                  Burkholderia                Flavobacterium
#                  0.0068890767                  0.0057336109
#                      Sneathia              Chryseobacterium
#                  0.0055628476                  0.0053282035
#                    Paracoccus              Methylobacterium
#                  0.0047714043                  0.0044918353
#                     Rhizobium                  Bdellovibrio
#                  0.0044333094                  0.0033255760
#                Fastidiosipila                     Moraxella
#                  0.0024519534                  0.0022040324
# Lachnospiracea_incertae_sedis                  Streptophyta
#                  0.0019148628                  0.0017120893
#                Bradyrhizobium                    Finegoldia
#                  0.0014877942                  0.0008458497
# [1] "Train mse: 0.769604379462047, Train Correlation: 0.884198766617219"
# [1] "Test mse: 0.83966559479537, Test Correlation: 0.89361290993002"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 9th repetition"
# [1] "Load data for repetition 9"
#                        Rothia                    Tropheryma
#                  0.2807444108                  0.1851103224
#             Propionibacterium                   Actinomyces
#                  0.0659044211                  0.0610736423
#                Pseudonocardia               Corynebacterium
#                  0.0418190640                  0.0296376497
#                     Atopobium                 Streptococcus
#                  0.0245605631                  0.0144762882
#                 Porphyromonas                    Prevotella
#                  0.0142906947                  0.0140453331
#                Granulicatella                 Lactobacillus
#                  0.0122994348                  0.0121669254
#                    Parvimonas                       Gemella
#                  0.0119018550                  0.0114553609
#                 Fusobacterium                Capnocytophaga
#                  0.0112375380                  0.0110213000
#                     Treponema                 Solobacterium
#                  0.0108471176                  0.0104802086
#                     Catonella     TM7_genera_incertae_sedis
#                  0.0102704074                  0.0101798319
#                   Veillonella                   Selenomonas
#                  0.0101132155                  0.0099816299
#                 Campylobacter     OD1_genera_incertae_sedis
#                  0.0098390871                  0.0097658645
#                Microbacterium                   Bacteroides
#                  0.0093593866                  0.0091348890
#                      Moryella                     Neisseria
#                  0.0090935831                  0.0079989194
#                   Megasphaera                Staphylococcus
#                  0.0070928923                  0.0068458781
#                  Oribacterium                    Filifactor
#                  0.0068356390                  0.0067755674
#                      Sneathia                   Haemophilus
#                  0.0067511292                  0.0065506618
#                Flavobacterium                  Burkholderia
#                  0.0065051697                  0.0052965574
#              Methylobacterium                  Sphingomonas
#                  0.0041951044                  0.0040472820
#              Chryseobacterium                  Bdellovibrio
#                  0.0034805213                  0.0031251260
#                     Moraxella                  Streptophyta
#                  0.0029012587                  0.0023148162
#                Bradyrhizobium                    Finegoldia
#                  0.0018254734                  0.0017316846
#                     Rhizobium                    Paracoccus
#                  0.0016348398                  0.0013551215
# Lachnospiracea_incertae_sedis                Fastidiosipila
#                  0.0012776452                  0.0006486881
# [1] "Train mse: 0.772786208957942, Train Correlation: 0.897158824542428"
# [1] "Test mse: 0.757290087505475, Test Correlation: 0.894467628117428"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"
# [1] "-----------------------------------------------------------------"
# [1] "Random Forest computation for 10th repetition"
# [1] "Load data for repetition 10"
#                        Rothia                    Tropheryma
#                  0.3026407498                  0.1715365653
#             Propionibacterium                   Actinomyces
#                  0.0671688120                  0.0576369683
#                Pseudonocardia               Corynebacterium
#                  0.0369203897                  0.0343747198
#     TM7_genera_incertae_sedis                     Atopobium
#                  0.0166451147                  0.0152873323
#                   Veillonella                     Treponema
#                  0.0134920371                  0.0124847761
#                       Gemella                 Streptococcus
#                  0.0124766485                  0.0122753281
#                 Porphyromonas                 Lactobacillus
#                  0.0120806787                  0.0118022141
#                Granulicatella                    Prevotella
#                  0.0114289744                  0.0113248746
#                 Solobacterium                 Fusobacterium
#                  0.0111748417                  0.0109512371
#                    Parvimonas                Capnocytophaga
#                  0.0108799565                  0.0108281726
#                   Bacteroides                   Selenomonas
#                  0.0106919193                  0.0098814701
#     OD1_genera_incertae_sedis                 Campylobacter
#                  0.0098609204                  0.0095400906
#                     Catonella                     Neisseria
#                  0.0093383693                  0.0088140413
#                      Moryella                Staphylococcus
#                  0.0087961622                  0.0085110979
#                    Filifactor                Microbacterium
#                  0.0082329007                  0.0070097420
#                  Burkholderia                      Sneathia
#                  0.0068539075                  0.0065089723
#                   Megasphaera                  Oribacterium
#                  0.0062586256                  0.0055836032
#                   Haemophilus                Flavobacterium
#                  0.0051067359                  0.0048229651
#                  Sphingomonas              Methylobacterium
#                  0.0047593377                  0.0045173771
#              Chryseobacterium                  Bdellovibrio
#                  0.0038960379                  0.0034224403
#                     Moraxella                     Rhizobium
#                  0.0024950344                  0.0024565392
#                    Paracoccus                  Streptophyta
#                  0.0020741876                  0.0017069452
# Lachnospiracea_incertae_sedis                Bradyrhizobium
#                  0.0016909160                  0.0016271201
#                Fastidiosipila                    Finegoldia
#                  0.0011682952                  0.0009638545
# [1] "Train mse: 0.759532391739722, Train Correlation: 0.891267359691574"
# [1] "Test mse: 0.762715907497515, Test Correlation: 0.886922086155061"
# [1] "FS sensitivity: 1, FS sensitivity: 0.105263157894737, FS gmeasure: 0.324442842261525, FS accuracy: 0.645833333333333"

# %%
results_table = res %>% t %>% data.frame
colnames(results_table) = c('Training MSE', 'Training Correlation', 'Test MSE', 'Test Correlation', 
                            'Taxa selection sensitivity','Taxa selection sensitivity',
                            'Taxa selection gmeasure', 'Taxa selection accuracy')
results_table
# Out:
#    Training MSE Training Correlation Test MSE  Test Correlation
# 1  0.7103146    0.9048869            0.8248670 0.8912506
# 2  0.7687064    0.8872230            0.7114735 0.9219048
# 3  0.7328649    0.9022667            0.7980956 0.8671227
# 4  0.8132727    0.8845817            0.6623301 0.8891512
# 5  0.7697988    0.9023046            0.8499341 0.8904468
# 6  0.6885309    0.9059698            0.7588928 0.8837913
# 7  0.7284909    0.8958500            0.7652187 0.8825066
# 8  0.7696044    0.8841988            0.8396656 0.8936129
# 9  0.7727862    0.8971588            0.7572901 0.8944676
# 10 0.7595324    0.8912674            0.7627159 0.8869221
#    Taxa selection sensitivity Taxa selection sensitivity
# 1  1                          0.1052632
# 2  1                          0.1052632
# 3  1                          0.1052632
# 4  1                          0.1052632
# 5  1                          0.1052632
# 6  1                          0.1052632
# 7  1                          0.1052632
# 8  1                          0.1052632
# 9  1                          0.1052632
# 10 1                          0.1052632
#    Taxa selection gmeasure Taxa selection accuracy
# 1  0.3244428               0.6458333
# 2  0.3244428               0.6458333
# 3  0.3244428               0.6458333
# 4  0.3244428               0.6458333
# 5  0.3244428               0.6458333
# 6  0.3244428               0.6458333
# 7  0.3244428               0.6458333
# 8  0.3244428               0.6458333
# 9  0.3244428               0.6458333
# 10 0.3244428               0.6458333

# %%
print('Mean')
apply(results_table, 2, mean)
# Out:
# [1] "Mean"
#               Training MSE       Training Correlation
#                  0.7513902                  0.8955708
#                   Test MSE           Test Correlation
#                  0.7730483                  0.8901177
# Taxa selection sensitivity Taxa selection sensitivity
#                  1.0000000                  0.1052632
#    Taxa selection gmeasure    Taxa selection accuracy
#                  0.3244428                  0.6458333

# %%
print('SD')
apply(results_table, 2, sd)
# Out:
# [1] "SD"
#               Training MSE       Training Correlation
#                 0.03625539                 0.00833999
#                   Test MSE           Test Correlation
#                 0.05805033                 0.01366592
# Taxa selection sensitivity Taxa selection sensitivity
#                 0.00000000                 0.00000000
#    Taxa selection gmeasure    Taxa selection accuracy
#                 0.00000000                 0.00000000
