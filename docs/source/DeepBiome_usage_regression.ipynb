# %% [markdown]
# # Getting start with the regression problem.
#
# Let's start with the baby step example for classification problem.
# Below is the basic example of the configuration for regression problem using example data contained in the package. For the required data type or more detailed configuration, please check the detailed information about each option in the [documantation](https://young-won.github.io/deepbiome/prerequisites.html#configuration) and detailed [examples](https://young-won.github.io/deepbiome/example_with_the_list_of_inputs.html)

# %%
from pkg_resources import resource_filename

# %%
network_info = {
    'model_info': {
        'network_class': 'DeepBiomeNetwork',
        'optimizer': 'adam',
        'lr': '0.01',
        'decay': '0.0001',
        'loss': 'mean_squared_error',
        'metrics': 'correlation_coefficient',
        'taxa_selection_metrics': 'sensitivity, specificity, gmeasure, accuracy',
        'reader_class': 'MicroBiomeRegressionReader',
        'normalizer': 'normalize_minmax',
    },
    'architecture_info': {
        'weight_initial': 'glorot_uniform',
        'weight_decay': 'phylogenetic_tree',
        'batch_normalization': 'False',
        'drop_out': '0',
    },
    'training_info': {
        'epochs': '100',
        'batch_size': '30', 
        'callbacks': 'ModelCheckpoint',
        'monitor': 'val_loss',
        'mode' : 'min',
        'min_delta': '1e-7',
    },
    'validation_info': {
        'validation_size': '0.2',
        'batch_size': 'None', 
    },
    'test_info': {
        'batch_size': 'None',
    },
}

path_info = {
    'data_info': {
        'data_path': resource_filename('deepbiome', 'tests/data'),
        'idx_path': resource_filename('deepbiome', 'tests/data/onefile_idx.csv'),
        'tree_info_path': resource_filename('deepbiome', 'tests/data/genus48_dic.csv'),
        'x_path': 'onefile_x.csv',
        'y_path': 'regression_y.csv'
    },
    'model_info': {
        'evaluation': 'eval.npy',
        'history': 'hist.json',
        'model_dir': './',
        'weight': 'weight.h5'
    }
}

# %% [markdown]
# For logging, we used the python logging library.

# %%
import logging

logging.basicConfig(format = '[%(name)-8s|%(levelname)s|%(filename)s:%(lineno)s] %(message)s',
                    level=logging.DEBUG)
log = logging.getLogger()

# %% [markdown]
# Here is the `deepbiome.deepbiome_train` function for training:

# %%
from deepbiome import deepbiome

test_evaluation, train_evaluation, network = deepbiome.deepbiome_train(log, network_info, path_info, number_of_fold=2)
# Out:
# Using TensorFlow backend.
# [root    |INFO|deepbiome.py:100] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:137] -------1 simulation start!----------------------------------
# [root    |INFO|readers.py:57] -----------------------------------------------------------------------
# [root    |INFO|readers.py:58] Construct Dataset
# [root    |INFO|readers.py:59] -----------------------------------------------------------------------
# [root    |INFO|readers.py:60] Load data
# [root    |INFO|deepbiome.py:147] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:148] Build network for 1 simulation
# [root    |INFO|build_network.py:506] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:507] Read phylogenetic tree information from /DATA/home/muha/github_repos/deepbiome/deepbiome/tests/data/genus48_dic.csv
# [root    |INFO|build_network.py:512] Phylogenetic tree level list: ['Genus', 'Family', 'Order', 'Class', 'Phylum']
# [root    |INFO|build_network.py:513] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:520]      Genus: 48
# [root    |INFO|build_network.py:520]     Family: 40
# [root    |INFO|build_network.py:520]      Order: 23
# [root    |INFO|build_network.py:520]      Class: 17
# [root    |INFO|build_network.py:520]     Phylum: 9
# [root    |INFO|build_network.py:524] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:525] Phylogenetic_tree_dict info: ['Order', 'Family', 'Number', 'Phylum', 'Class', 'Genus']
# [root    |INFO|build_network.py:526] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:536] Build edge weights between [ Genus, Family]
# [root    |INFO|build_network.py:536] Build edge weights between [Family,  Order]
# [root    |INFO|build_network.py:536] Build edge weights between [ Order,  Class]
# [root    |INFO|build_network.py:536] Build edge weights between [ Class, Phylum]
# [root    |INFO|build_network.py:549] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:557] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:558] Build network based on phylogenetic tree information
# [root    |INFO|build_network.py:559] ------------------------------------------------------------------------------------------
# [tensorflow|WARNING|deprecation.py:328] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/resource_variable_ops.py:432: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# [root    |INFO|build_network.py:636] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:57] Build Network
# [root    |INFO|build_network.py:58] Optimizer = adam
# [root    |INFO|build_network.py:59] Loss = mean_squared_error
# [root    |INFO|build_network.py:60] Metrics = correlation_coefficient
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 48)                0
# _________________________________________________________________
# l1_dense (Dense_with_tree)   (None, 40)                1960
# _________________________________________________________________
# l1_activation (Activation)   (None, 40)                0
# _________________________________________________________________
# l2_dense (Dense_with_tree)   (None, 23)                943
# _________________________________________________________________
# l2_activation (Activation)   (None, 23)                0
# _________________________________________________________________
# l3_dense (Dense_with_tree)   (None, 17)                408
# _________________________________________________________________
# l3_activation (Activation)   (None, 17)                0
# _________________________________________________________________
# l4_dense (Dense_with_tree)   (None, 9)                 162
# _________________________________________________________________
# l4_activation (Activation)   (None, 9)                 0
# _________________________________________________________________
# last_dense_h (Dense)         (None, 1)                 10
# _________________________________________________________________
# p_hat (Activation)           (None, 1)                 0
# =================================================================
# Total params: 3,483
# Trainable params: 3,483
# Non-trainable params: 0
# _________________________________________________________________
# [root    |INFO|deepbiome.py:157] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:158] 1 fold computing start!----------------------------------
# [root    |INFO|build_network.py:133] Training start!
# [tensorflow|WARNING|deprecation.py:328] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:2862: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 640 samples, validate on 160 samples
# Epoch 1/100
# 640/640 [==============================] - 1s 1ms/step - loss: 14.3489 - correlation_coefficient: 0.0096 - val_loss: 9.1113 - val_correlation_coefficient: 0.0929
# Epoch 2/100
# 640/640 [==============================] - 0s 270us/step - loss: 4.1674 - correlation_coefficient: 0.1044 - val_loss: 2.7463 - val_correlation_coefficient: 0.1798
# Epoch 3/100
# 640/640 [==============================] - 0s 278us/step - loss: 2.8050 - correlation_coefficient: 0.1159 - val_loss: 2.6230 - val_correlation_coefficient: 0.1666
# Epoch 4/100
# 640/640 [==============================] - 0s 257us/step - loss: 2.6471 - correlation_coefficient: 0.1555 - val_loss: 2.4429 - val_correlation_coefficient: 0.2171
# Epoch 5/100
# 640/640 [==============================] - 0s 266us/step - loss: 2.6405 - correlation_coefficient: 0.2494 - val_loss: 2.5521 - val_correlation_coefficient: 0.2999
# Epoch 6/100
# 640/640 [==============================] - 0s 279us/step - loss: 2.6437 - correlation_coefficient: 0.3804 - val_loss: 2.4545 - val_correlation_coefficient: 0.4372
# Epoch 7/100
# 640/640 [==============================] - 0s 273us/step - loss: 2.5880 - correlation_coefficient: 0.4589 - val_loss: 2.4003 - val_correlation_coefficient: 0.4982
# Epoch 8/100
# 640/640 [==============================] - 0s 276us/step - loss: 2.4335 - correlation_coefficient: 0.5007 - val_loss: 2.1831 - val_correlation_coefficient: 0.4879
# Epoch 9/100
# 640/640 [==============================] - 0s 278us/step - loss: 2.2158 - correlation_coefficient: 0.4848 - val_loss: 2.0716 - val_correlation_coefficient: 0.4703
# Epoch 10/100
# 640/640 [==============================] - 0s 276us/step - loss: 2.1383 - correlation_coefficient: 0.4971 - val_loss: 2.2864 - val_correlation_coefficient: 0.4810
# Epoch 11/100
# 640/640 [==============================] - 0s 276us/step - loss: 2.1639 - correlation_coefficient: 0.5117 - val_loss: 2.0578 - val_correlation_coefficient: 0.4811
# Epoch 12/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.1542 - correlation_coefficient: 0.4982 - val_loss: 2.1871 - val_correlation_coefficient: 0.4915
# Epoch 13/100
# 640/640 [==============================] - 0s 266us/step - loss: 2.1414 - correlation_coefficient: 0.4991 - val_loss: 2.2181 - val_correlation_coefficient: 0.4971
# Epoch 14/100
# 640/640 [==============================] - 0s 270us/step - loss: 2.1352 - correlation_coefficient: 0.4859 - val_loss: 2.2693 - val_correlation_coefficient: 0.5003
# Epoch 15/100
# 640/640 [==============================] - 0s 272us/step - loss: 2.1407 - correlation_coefficient: 0.4952 - val_loss: 2.1387 - val_correlation_coefficient: 0.5044
# Epoch 16/100
# 640/640 [==============================] - 0s 287us/step - loss: 2.1192 - correlation_coefficient: 0.4863 - val_loss: 2.2153 - val_correlation_coefficient: 0.5066
# Epoch 17/100
# 640/640 [==============================] - 0s 265us/step - loss: 2.1214 - correlation_coefficient: 0.4969 - val_loss: 2.1241 - val_correlation_coefficient: 0.5101
# Epoch 18/100
# 640/640 [==============================] - 0s 268us/step - loss: 2.0896 - correlation_coefficient: 0.5137 - val_loss: 2.0221 - val_correlation_coefficient: 0.5133
# Epoch 19/100
# 640/640 [==============================] - 0s 272us/step - loss: 2.1153 - correlation_coefficient: 0.4977 - val_loss: 2.2208 - val_correlation_coefficient: 0.5180
# Epoch 20/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.1094 - correlation_coefficient: 0.5223 - val_loss: 2.4077 - val_correlation_coefficient: 0.5180
# Epoch 21/100
# 640/640 [==============================] - 0s 282us/step - loss: 2.1291 - correlation_coefficient: 0.5031 - val_loss: 2.2024 - val_correlation_coefficient: 0.5232
# Epoch 22/100
# 640/640 [==============================] - 0s 280us/step - loss: 2.0954 - correlation_coefficient: 0.5049 - val_loss: 2.1498 - val_correlation_coefficient: 0.5270
# Epoch 23/100
# 640/640 [==============================] - 0s 276us/step - loss: 2.1264 - correlation_coefficient: 0.5068 - val_loss: 2.1899 - val_correlation_coefficient: 0.5296
# Epoch 24/100
# 640/640 [==============================] - 0s 276us/step - loss: 2.0841 - correlation_coefficient: 0.5475 - val_loss: 2.1175 - val_correlation_coefficient: 0.5328
# Epoch 25/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.0556 - correlation_coefficient: 0.5383 - val_loss: 2.0243 - val_correlation_coefficient: 0.5357
# Epoch 26/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.0691 - correlation_coefficient: 0.5139 - val_loss: 1.9954 - val_correlation_coefficient: 0.5396
# Epoch 27/100
# 640/640 [==============================] - 0s 271us/step - loss: 2.0863 - correlation_coefficient: 0.5337 - val_loss: 1.9742 - val_correlation_coefficient: 0.5428
# Epoch 28/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.0326 - correlation_coefficient: 0.5421 - val_loss: 2.1952 - val_correlation_coefficient: 0.5440
# Epoch 29/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.0750 - correlation_coefficient: 0.5357 - val_loss: 1.9725 - val_correlation_coefficient: 0.5488
# Epoch 30/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.0364 - correlation_coefficient: 0.5252 - val_loss: 2.0232 - val_correlation_coefficient: 0.5512
# Epoch 31/100
# 640/640 [==============================] - 0s 268us/step - loss: 2.0711 - correlation_coefficient: 0.5466 - val_loss: 1.9657 - val_correlation_coefficient: 0.5551
# Epoch 32/100
# 640/640 [==============================] - 0s 261us/step - loss: 2.0114 - correlation_coefficient: 0.5306 - val_loss: 2.0649 - val_correlation_coefficient: 0.5572
# Epoch 33/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.0123 - correlation_coefficient: 0.5546 - val_loss: 2.0118 - val_correlation_coefficient: 0.5617
# Epoch 34/100
# 640/640 [==============================] - 0s 261us/step - loss: 2.0148 - correlation_coefficient: 0.5332 - val_loss: 2.0389 - val_correlation_coefficient: 0.5645
# Epoch 35/100
# 640/640 [==============================] - 0s 266us/step - loss: 1.9953 - correlation_coefficient: 0.5394 - val_loss: 2.0098 - val_correlation_coefficient: 0.5683
# Epoch 36/100
# 640/640 [==============================] - 0s 253us/step - loss: 1.9959 - correlation_coefficient: 0.5785 - val_loss: 2.0579 - val_correlation_coefficient: 0.5724
# Epoch 37/100
# 640/640 [==============================] - 0s 272us/step - loss: 1.9603 - correlation_coefficient: 0.5629 - val_loss: 1.8944 - val_correlation_coefficient: 0.5742
# Epoch 38/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.0638 - correlation_coefficient: 0.5610 - val_loss: 2.1154 - val_correlation_coefficient: 0.5786
# Epoch 39/100
# 640/640 [==============================] - 0s 266us/step - loss: 2.0402 - correlation_coefficient: 0.5713 - val_loss: 1.9418 - val_correlation_coefficient: 0.5790
# Epoch 40/100
# 640/640 [==============================] - 0s 260us/step - loss: 1.9264 - correlation_coefficient: 0.5650 - val_loss: 1.9474 - val_correlation_coefficient: 0.5815
# Epoch 41/100
# 640/640 [==============================] - 0s 272us/step - loss: 1.9196 - correlation_coefficient: 0.5774 - val_loss: 2.0513 - val_correlation_coefficient: 0.5846
# Epoch 42/100
# 640/640 [==============================] - 0s 271us/step - loss: 1.9049 - correlation_coefficient: 0.5791 - val_loss: 1.8457 - val_correlation_coefficient: 0.5862
# Epoch 43/100
# 640/640 [==============================] - 0s 277us/step - loss: 1.9238 - correlation_coefficient: 0.5985 - val_loss: 1.9115 - val_correlation_coefficient: 0.5897
# Epoch 44/100
# 640/640 [==============================] - 0s 262us/step - loss: 1.8996 - correlation_coefficient: 0.5780 - val_loss: 1.8931 - val_correlation_coefficient: 0.5917
# Epoch 45/100
# 640/640 [==============================] - 0s 272us/step - loss: 1.8799 - correlation_coefficient: 0.5890 - val_loss: 1.9429 - val_correlation_coefficient: 0.5934
# Epoch 46/100
# 640/640 [==============================] - 0s 275us/step - loss: 1.8438 - correlation_coefficient: 0.5857 - val_loss: 1.8895 - val_correlation_coefficient: 0.5957
# Epoch 47/100
# 640/640 [==============================] - 0s 273us/step - loss: 1.8081 - correlation_coefficient: 0.6064 - val_loss: 1.8048 - val_correlation_coefficient: 0.5985
# Epoch 48/100
# 640/640 [==============================] - 0s 269us/step - loss: 1.8121 - correlation_coefficient: 0.6149 - val_loss: 1.8389 - val_correlation_coefficient: 0.6000
# Epoch 49/100
# 640/640 [==============================] - 0s 266us/step - loss: 1.8046 - correlation_coefficient: 0.6192 - val_loss: 1.7700 - val_correlation_coefficient: 0.6022
# Epoch 50/100
# 640/640 [==============================] - 0s 261us/step - loss: 1.8077 - correlation_coefficient: 0.6206 - val_loss: 1.9409 - val_correlation_coefficient: 0.6039
# Epoch 51/100
# 640/640 [==============================] - 0s 281us/step - loss: 1.7650 - correlation_coefficient: 0.6319 - val_loss: 1.7547 - val_correlation_coefficient: 0.6069
# Epoch 52/100
# 640/640 [==============================] - 0s 276us/step - loss: 1.7113 - correlation_coefficient: 0.6429 - val_loss: 1.9923 - val_correlation_coefficient: 0.6077
# Epoch 53/100
# 640/640 [==============================] - 0s 271us/step - loss: 1.6936 - correlation_coefficient: 0.6352 - val_loss: 1.7292 - val_correlation_coefficient: 0.6108
# Epoch 54/100
# 640/640 [==============================] - 0s 283us/step - loss: 1.7417 - correlation_coefficient: 0.6520 - val_loss: 2.1553 - val_correlation_coefficient: 0.6098
# Epoch 55/100
# 640/640 [==============================] - 0s 268us/step - loss: 1.7700 - correlation_coefficient: 0.6511 - val_loss: 1.6973 - val_correlation_coefficient: 0.6133
# Epoch 56/100
# 640/640 [==============================] - 0s 273us/step - loss: 1.6356 - correlation_coefficient: 0.6463 - val_loss: 1.7688 - val_correlation_coefficient: 0.6143
# Epoch 57/100
# 640/640 [==============================] - 0s 253us/step - loss: 1.5936 - correlation_coefficient: 0.6426 - val_loss: 1.6815 - val_correlation_coefficient: 0.6153
# Epoch 58/100
# 640/640 [==============================] - 0s 268us/step - loss: 1.5695 - correlation_coefficient: 0.6740 - val_loss: 1.6692 - val_correlation_coefficient: 0.6153
# Epoch 59/100
# 640/640 [==============================] - 0s 272us/step - loss: 1.5448 - correlation_coefficient: 0.6597 - val_loss: 1.6869 - val_correlation_coefficient: 0.6151
# Epoch 60/100
# 640/640 [==============================] - 0s 276us/step - loss: 1.5403 - correlation_coefficient: 0.6780 - val_loss: 1.6848 - val_correlation_coefficient: 0.6140
# Epoch 61/100
# 640/640 [==============================] - 0s 277us/step - loss: 1.5260 - correlation_coefficient: 0.6735 - val_loss: 1.6237 - val_correlation_coefficient: 0.6166
# Epoch 62/100
# 640/640 [==============================] - 0s 275us/step - loss: 1.5345 - correlation_coefficient: 0.7006 - val_loss: 1.8510 - val_correlation_coefficient: 0.6147
# Epoch 63/100
# 640/640 [==============================] - 0s 270us/step - loss: 1.5214 - correlation_coefficient: 0.6955 - val_loss: 1.8124 - val_correlation_coefficient: 0.6139
# Epoch 64/100
# 640/640 [==============================] - 0s 270us/step - loss: 1.4632 - correlation_coefficient: 0.6986 - val_loss: 1.6586 - val_correlation_coefficient: 0.6120
# Epoch 65/100
# 640/640 [==============================] - 0s 268us/step - loss: 1.4516 - correlation_coefficient: 0.6956 - val_loss: 1.6091 - val_correlation_coefficient: 0.6143
# Epoch 66/100
# 640/640 [==============================] - 0s 269us/step - loss: 1.4618 - correlation_coefficient: 0.7063 - val_loss: 1.6684 - val_correlation_coefficient: 0.6147
# Epoch 67/100
# 640/640 [==============================] - 0s 283us/step - loss: 1.4274 - correlation_coefficient: 0.7177 - val_loss: 1.9327 - val_correlation_coefficient: 0.6114
# Epoch 68/100
# 640/640 [==============================] - 0s 274us/step - loss: 1.4012 - correlation_coefficient: 0.7156 - val_loss: 1.6019 - val_correlation_coefficient: 0.6090
# Epoch 69/100
# 640/640 [==============================] - 0s 275us/step - loss: 1.3617 - correlation_coefficient: 0.7221 - val_loss: 1.7525 - val_correlation_coefficient: 0.6090
# Epoch 70/100
# 640/640 [==============================] - 0s 275us/step - loss: 1.3719 - correlation_coefficient: 0.7055 - val_loss: 1.6044 - val_correlation_coefficient: 0.6092
# Epoch 71/100
# 640/640 [==============================] - 0s 264us/step - loss: 1.4085 - correlation_coefficient: 0.7147 - val_loss: 1.7121 - val_correlation_coefficient: 0.6100
# Epoch 72/100
# 640/640 [==============================] - 0s 269us/step - loss: 1.3395 - correlation_coefficient: 0.7134 - val_loss: 1.6079 - val_correlation_coefficient: 0.6082
# Epoch 73/100
# 640/640 [==============================] - 0s 272us/step - loss: 1.4113 - correlation_coefficient: 0.7207 - val_loss: 1.6043 - val_correlation_coefficient: 0.6081
# Epoch 74/100
# 640/640 [==============================] - 0s 260us/step - loss: 1.3890 - correlation_coefficient: 0.7188 - val_loss: 1.6102 - val_correlation_coefficient: 0.6097
# Epoch 75/100
# 640/640 [==============================] - 0s 265us/step - loss: 1.3752 - correlation_coefficient: 0.7143 - val_loss: 1.7767 - val_correlation_coefficient: 0.6124
# Epoch 76/100
# 640/640 [==============================] - 0s 264us/step - loss: 1.3354 - correlation_coefficient: 0.7208 - val_loss: 1.7415 - val_correlation_coefficient: 0.6128
# Epoch 77/100
# 640/640 [==============================] - 0s 270us/step - loss: 1.3068 - correlation_coefficient: 0.7220 - val_loss: 1.8542 - val_correlation_coefficient: 0.6104
# Epoch 78/100
# 640/640 [==============================] - 0s 270us/step - loss: 1.3091 - correlation_coefficient: 0.7236 - val_loss: 1.6378 - val_correlation_coefficient: 0.6128
# Epoch 79/100
# 640/640 [==============================] - 0s 258us/step - loss: 1.3314 - correlation_coefficient: 0.7345 - val_loss: 1.6372 - val_correlation_coefficient: 0.6114
# Epoch 80/100
# 640/640 [==============================] - 0s 275us/step - loss: 1.3033 - correlation_coefficient: 0.7357 - val_loss: 1.6466 - val_correlation_coefficient: 0.6132
# Epoch 81/100
# 640/640 [==============================] - 0s 280us/step - loss: 1.2842 - correlation_coefficient: 0.7232 - val_loss: 1.6769 - val_correlation_coefficient: 0.6123
# Epoch 82/100
# 640/640 [==============================] - 0s 275us/step - loss: 1.2773 - correlation_coefficient: 0.7209 - val_loss: 1.6046 - val_correlation_coefficient: 0.6123
# Epoch 83/100
# 640/640 [==============================] - 0s 258us/step - loss: 1.2681 - correlation_coefficient: 0.7324 - val_loss: 1.6096 - val_correlation_coefficient: 0.6128
# Epoch 84/100
# 640/640 [==============================] - 0s 256us/step - loss: 1.3020 - correlation_coefficient: 0.7364 - val_loss: 1.7800 - val_correlation_coefficient: 0.6148
# Epoch 85/100
# 640/640 [==============================] - 0s 288us/step - loss: 1.3462 - correlation_coefficient: 0.7376 - val_loss: 1.6114 - val_correlation_coefficient: 0.6154
# Epoch 86/100
# 640/640 [==============================] - 0s 268us/step - loss: 1.2925 - correlation_coefficient: 0.7437 - val_loss: 1.6499 - val_correlation_coefficient: 0.6166
# Epoch 87/100
# 640/640 [==============================] - 0s 274us/step - loss: 1.2908 - correlation_coefficient: 0.7370 - val_loss: 1.5691 - val_correlation_coefficient: 0.6165
# Epoch 88/100
# 640/640 [==============================] - 0s 285us/step - loss: 1.2483 - correlation_coefficient: 0.7343 - val_loss: 1.9124 - val_correlation_coefficient: 0.6169
# Epoch 89/100
# 640/640 [==============================] - 0s 272us/step - loss: 1.3791 - correlation_coefficient: 0.7370 - val_loss: 1.5673 - val_correlation_coefficient: 0.6206
# Epoch 90/100
# 640/640 [==============================] - 0s 272us/step - loss: 1.2717 - correlation_coefficient: 0.7401 - val_loss: 1.5647 - val_correlation_coefficient: 0.6247
# Epoch 91/100
# 640/640 [==============================] - 0s 276us/step - loss: 1.2605 - correlation_coefficient: 0.7442 - val_loss: 1.6420 - val_correlation_coefficient: 0.6237
# Epoch 92/100
# 640/640 [==============================] - 0s 260us/step - loss: 1.2334 - correlation_coefficient: 0.7328 - val_loss: 1.5713 - val_correlation_coefficient: 0.6217
# Epoch 93/100
# 640/640 [==============================] - 0s 266us/step - loss: 1.2235 - correlation_coefficient: 0.7381 - val_loss: 1.5779 - val_correlation_coefficient: 0.6236
# Epoch 94/100
# 640/640 [==============================] - 0s 269us/step - loss: 1.2359 - correlation_coefficient: 0.7454 - val_loss: 1.7685 - val_correlation_coefficient: 0.6232
# Epoch 95/100
# 640/640 [==============================] - 0s 276us/step - loss: 1.2666 - correlation_coefficient: 0.7406 - val_loss: 1.7199 - val_correlation_coefficient: 0.6230
# Epoch 96/100
# 640/640 [==============================] - 0s 253us/step - loss: 1.3046 - correlation_coefficient: 0.7487 - val_loss: 1.5645 - val_correlation_coefficient: 0.6220
# Epoch 97/100
# 640/640 [==============================] - 0s 262us/step - loss: 1.2456 - correlation_coefficient: 0.7551 - val_loss: 1.7898 - val_correlation_coefficient: 0.6259
# Epoch 98/100
# 640/640 [==============================] - 0s 258us/step - loss: 1.2038 - correlation_coefficient: 0.7464 - val_loss: 1.7173 - val_correlation_coefficient: 0.6276
# Epoch 99/100
# 640/640 [==============================] - 0s 275us/step - loss: 1.1905 - correlation_coefficient: 0.7521 - val_loss: 1.9001 - val_correlation_coefficient: 0.6268
# Epoch 100/100
# 640/640 [==============================] - 0s 260us/step - loss: 1.3076 - correlation_coefficient: 0.7530 - val_loss: 1.5701 - val_correlation_coefficient: 0.6278
# [root    |INFO|build_network.py:83] Load trained model weight at ./weight_0.h5
# [root    |INFO|build_network.py:143] Training end with time 20.99549651145935!
# [root    |INFO|build_network.py:79] Saved trained model weight at ./weight_0.h5
# [root    |DEBUG|deepbiome.py:166] Save weight at ./weight_0.h5
# [root    |DEBUG|deepbiome.py:169] Save history at ./hist_0.json
# [root    |INFO|build_network.py:169] Evaluation start!
# 800/800 [==============================] - 0s 5us/step
# [root    |INFO|build_network.py:174] Evaluation end with time 0.0075337886810302734!
# [root    |INFO|build_network.py:175] Evaluation: [1.3598358631134033, 0.7157667279243469]
# [root    |INFO|build_network.py:169] Evaluation start!
# 200/200 [==============================] - 0s 18us/step
# [root    |INFO|build_network.py:174] Evaluation end with time 0.006311893463134766!
# [root    |INFO|build_network.py:175] Evaluation: [1.7086390256881714, 0.6604333519935608]
# [root    |INFO|deepbiome.py:180] Compute time : 23.23722743988037
# [root    |INFO|deepbiome.py:181] 1 fold computing end!---------------------------------------------
# [root    |INFO|deepbiome.py:137] -------2 simulation start!----------------------------------
# [root    |INFO|readers.py:57] -----------------------------------------------------------------------
# [root    |INFO|readers.py:58] Construct Dataset
# [root    |INFO|readers.py:59] -----------------------------------------------------------------------
# [root    |INFO|readers.py:60] Load data
# [root    |INFO|deepbiome.py:147] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:148] Build network for 2 simulation
# [root    |INFO|build_network.py:506] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:507] Read phylogenetic tree information from /DATA/home/muha/github_repos/deepbiome/deepbiome/tests/data/genus48_dic.csv
# [root    |INFO|build_network.py:512] Phylogenetic tree level list: ['Genus', 'Family', 'Order', 'Class', 'Phylum']
# [root    |INFO|build_network.py:513] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:520]      Genus: 48
# [root    |INFO|build_network.py:520]     Family: 40
# [root    |INFO|build_network.py:520]      Order: 23
# [root    |INFO|build_network.py:520]      Class: 17
# [root    |INFO|build_network.py:520]     Phylum: 9
# [root    |INFO|build_network.py:524] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:525] Phylogenetic_tree_dict info: ['Order', 'Family', 'Number', 'Phylum', 'Class', 'Genus']
# [root    |INFO|build_network.py:526] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:536] Build edge weights between [ Genus, Family]
# [root    |INFO|build_network.py:536] Build edge weights between [Family,  Order]
# [root    |INFO|build_network.py:536] Build edge weights between [ Order,  Class]
# [root    |INFO|build_network.py:536] Build edge weights between [ Class, Phylum]
# [root    |INFO|build_network.py:549] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:557] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:558] Build network based on phylogenetic tree information
# [root    |INFO|build_network.py:559] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:636] ------------------------------------------------------------------------------------------
# [root    |INFO|build_network.py:57] Build Network
# [root    |INFO|build_network.py:58] Optimizer = adam
# [root    |INFO|build_network.py:59] Loss = mean_squared_error
# [root    |INFO|build_network.py:60] Metrics = correlation_coefficient
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 48)                0
# _________________________________________________________________
# l1_dense (Dense_with_tree)   (None, 40)                1960
# _________________________________________________________________
# l1_activation (Activation)   (None, 40)                0
# _________________________________________________________________
# l2_dense (Dense_with_tree)   (None, 23)                943
# _________________________________________________________________
# l2_activation (Activation)   (None, 23)                0
# _________________________________________________________________
# l3_dense (Dense_with_tree)   (None, 17)                408
# _________________________________________________________________
# l3_activation (Activation)   (None, 17)                0
# _________________________________________________________________
# l4_dense (Dense_with_tree)   (None, 9)                 162
# _________________________________________________________________
# l4_activation (Activation)   (None, 9)                 0
# _________________________________________________________________
# last_dense_h (Dense)         (None, 1)                 10
# _________________________________________________________________
# p_hat (Activation)           (None, 1)                 0
# =================================================================
# Total params: 3,483
# Trainable params: 3,483
# Non-trainable params: 0
# _________________________________________________________________
# [root    |INFO|deepbiome.py:157] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:158] 2 fold computing start!----------------------------------
# [root    |INFO|build_network.py:133] Training start!
# Train on 640 samples, validate on 160 samples
# Epoch 1/100
# 640/640 [==============================] - 0s 661us/step - loss: 16.8343 - correlation_coefficient: 0.0199 - val_loss: 14.3591 - val_correlation_coefficient: -0.0170
# Epoch 2/100
# 640/640 [==============================] - 0s 263us/step - loss: 9.5261 - correlation_coefficient: 0.0083 - val_loss: 4.5716 - val_correlation_coefficient: -0.0015
# Epoch 3/100
# 640/640 [==============================] - 0s 258us/step - loss: 2.9696 - correlation_coefficient: 0.0258 - val_loss: 2.5954 - val_correlation_coefficient: 0.0139
# Epoch 4/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.5998 - correlation_coefficient: 0.0474 - val_loss: 2.5343 - val_correlation_coefficient: 0.0079
# Epoch 5/100
# 640/640 [==============================] - 0s 259us/step - loss: 2.5906 - correlation_coefficient: 0.0742 - val_loss: 2.4447 - val_correlation_coefficient: 0.0176
# Epoch 6/100
# 640/640 [==============================] - 0s 260us/step - loss: 2.5990 - correlation_coefficient: 0.0794 - val_loss: 2.4988 - val_correlation_coefficient: 0.0272
# Epoch 7/100
# 640/640 [==============================] - 0s 251us/step - loss: 2.6095 - correlation_coefficient: 0.0814 - val_loss: 2.4476 - val_correlation_coefficient: 0.0398
# Epoch 8/100
# 640/640 [==============================] - 0s 239us/step - loss: 2.5880 - correlation_coefficient: 0.1147 - val_loss: 2.4571 - val_correlation_coefficient: 0.0492
# Epoch 9/100
# 640/640 [==============================] - 0s 258us/step - loss: 2.5991 - correlation_coefficient: 0.0882 - val_loss: 2.4798 - val_correlation_coefficient: 0.0625
# Epoch 10/100
# 640/640 [==============================] - 0s 290us/step - loss: 2.5925 - correlation_coefficient: 0.1122 - val_loss: 2.4496 - val_correlation_coefficient: 0.0692
# Epoch 11/100
# 640/640 [==============================] - 0s 280us/step - loss: 2.6124 - correlation_coefficient: 0.1032 - val_loss: 2.5063 - val_correlation_coefficient: 0.0828
# Epoch 12/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.5860 - correlation_coefficient: 0.1331 - val_loss: 2.4480 - val_correlation_coefficient: 0.0991
# Epoch 13/100
# 640/640 [==============================] - 0s 280us/step - loss: 2.5896 - correlation_coefficient: 0.1269 - val_loss: 2.4492 - val_correlation_coefficient: 0.1128
# Epoch 14/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.5914 - correlation_coefficient: 0.1299 - val_loss: 2.4473 - val_correlation_coefficient: 0.1168
# Epoch 15/100
# 640/640 [==============================] - 0s 259us/step - loss: 2.5941 - correlation_coefficient: 0.1262 - val_loss: 2.4972 - val_correlation_coefficient: 0.1222
# Epoch 16/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.5865 - correlation_coefficient: 0.1443 - val_loss: 2.4460 - val_correlation_coefficient: 0.1242
# Epoch 17/100
# 640/640 [==============================] - 0s 262us/step - loss: 2.5880 - correlation_coefficient: 0.1517 - val_loss: 2.4573 - val_correlation_coefficient: 0.1257
# Epoch 18/100
# 640/640 [==============================] - 0s 264us/step - loss: 2.5938 - correlation_coefficient: 0.1354 - val_loss: 2.4741 - val_correlation_coefficient: 0.1400
# Epoch 19/100
# 640/640 [==============================] - 0s 254us/step - loss: 2.5899 - correlation_coefficient: 0.1553 - val_loss: 2.4709 - val_correlation_coefficient: 0.1198
# Epoch 20/100
# 640/640 [==============================] - 0s 258us/step - loss: 2.5937 - correlation_coefficient: 0.1312 - val_loss: 2.4441 - val_correlation_coefficient: 0.1158
# Epoch 21/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.5840 - correlation_coefficient: 0.1591 - val_loss: 2.5173 - val_correlation_coefficient: 0.1145
# Epoch 22/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.6079 - correlation_coefficient: 0.1739 - val_loss: 2.4487 - val_correlation_coefficient: 0.1125
# Epoch 23/100
# 640/640 [==============================] - 0s 276us/step - loss: 2.5899 - correlation_coefficient: 0.1566 - val_loss: 2.4531 - val_correlation_coefficient: 0.1083
# Epoch 24/100
# 640/640 [==============================] - 0s 274us/step - loss: 2.5852 - correlation_coefficient: 0.1683 - val_loss: 2.4459 - val_correlation_coefficient: 0.1074
# Epoch 25/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.5931 - correlation_coefficient: 0.1638 - val_loss: 2.5450 - val_correlation_coefficient: 0.1053
# Epoch 26/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.6094 - correlation_coefficient: 0.1510 - val_loss: 2.4502 - val_correlation_coefficient: 0.1020
# Epoch 27/100
# 640/640 [==============================] - 0s 263us/step - loss: 2.6154 - correlation_coefficient: 0.1346 - val_loss: 2.4527 - val_correlation_coefficient: 0.1023
# Epoch 28/100
# 640/640 [==============================] - 0s 272us/step - loss: 2.5948 - correlation_coefficient: 0.1499 - val_loss: 2.4433 - val_correlation_coefficient: 0.1072
# Epoch 29/100
# 640/640 [==============================] - 0s 259us/step - loss: 2.5953 - correlation_coefficient: 0.1398 - val_loss: 2.4480 - val_correlation_coefficient: 0.1283
# Epoch 30/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.5856 - correlation_coefficient: 0.1114 - val_loss: 2.4430 - val_correlation_coefficient: 0.1493
# Epoch 31/100
# 640/640 [==============================] - 0s 270us/step - loss: 2.5901 - correlation_coefficient: 0.1234 - val_loss: 2.4404 - val_correlation_coefficient: 0.1485
# Epoch 32/100
# 640/640 [==============================] - 0s 270us/step - loss: 2.6312 - correlation_coefficient: 0.1331 - val_loss: 2.4404 - val_correlation_coefficient: 0.1382
# Epoch 33/100
# 640/640 [==============================] - 0s 273us/step - loss: 2.5869 - correlation_coefficient: 0.1448 - val_loss: 2.4487 - val_correlation_coefficient: 0.1536
# Epoch 34/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.5746 - correlation_coefficient: 0.0515 - val_loss: 2.4344 - val_correlation_coefficient: 0.0673
# Epoch 35/100
# 640/640 [==============================] - 0s 260us/step - loss: 2.6008 - correlation_coefficient: 0.0927 - val_loss: 2.5337 - val_correlation_coefficient: 0.0753
# Epoch 36/100
# 640/640 [==============================] - 0s 273us/step - loss: 2.5869 - correlation_coefficient: 0.0869 - val_loss: 2.4506 - val_correlation_coefficient: 0.0851
# Epoch 37/100
# 640/640 [==============================] - 0s 264us/step - loss: 2.5798 - correlation_coefficient: 0.0839 - val_loss: 2.4542 - val_correlation_coefficient: 0.0813
# Epoch 38/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.5789 - correlation_coefficient: 0.0818 - val_loss: 2.4498 - val_correlation_coefficient: 0.0783
# Epoch 39/100
# 640/640 [==============================] - 0s 274us/step - loss: 2.5735 - correlation_coefficient: 0.1021 - val_loss: 2.4706 - val_correlation_coefficient: 0.0778
# Epoch 40/100
# 640/640 [==============================] - 0s 255us/step - loss: 2.5824 - correlation_coefficient: 0.0961 - val_loss: 2.4393 - val_correlation_coefficient: 0.0735
# Epoch 41/100
# 640/640 [==============================] - 0s 271us/step - loss: 2.6031 - correlation_coefficient: 0.1096 - val_loss: 2.4397 - val_correlation_coefficient: 0.0746
# Epoch 42/100
# 640/640 [==============================] - 0s 268us/step - loss: 2.5665 - correlation_coefficient: 0.1048 - val_loss: 2.4436 - val_correlation_coefficient: 0.0781
# Epoch 43/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.5831 - correlation_coefficient: 0.0772 - val_loss: 2.4420 - val_correlation_coefficient: 0.0794
# Epoch 44/100
# 640/640 [==============================] - 0s 273us/step - loss: 2.5998 - correlation_coefficient: 0.1082 - val_loss: 2.4378 - val_correlation_coefficient: 0.0774
# Epoch 45/100
# 640/640 [==============================] - 0s 268us/step - loss: 2.5797 - correlation_coefficient: 0.1254 - val_loss: 2.4487 - val_correlation_coefficient: 0.0769
# Epoch 46/100
# 640/640 [==============================] - 0s 268us/step - loss: 2.5841 - correlation_coefficient: 0.0799 - val_loss: 2.4350 - val_correlation_coefficient: 0.0735
# Epoch 47/100
# 640/640 [==============================] - 0s 271us/step - loss: 2.5876 - correlation_coefficient: 0.1293 - val_loss: 2.4360 - val_correlation_coefficient: 0.0672
# Epoch 48/100
# 640/640 [==============================] - 0s 278us/step - loss: 2.5659 - correlation_coefficient: 0.1138 - val_loss: 2.4479 - val_correlation_coefficient: 0.0696
# Epoch 49/100
# 640/640 [==============================] - 0s 290us/step - loss: 2.5747 - correlation_coefficient: 0.1518 - val_loss: 2.4437 - val_correlation_coefficient: 0.0691
# Epoch 50/100
# 640/640 [==============================] - 0s 265us/step - loss: 2.5555 - correlation_coefficient: 0.1133 - val_loss: 2.5335 - val_correlation_coefficient: 0.0645
# Epoch 51/100
# 640/640 [==============================] - 0s 274us/step - loss: 2.5789 - correlation_coefficient: 0.1242 - val_loss: 2.4379 - val_correlation_coefficient: 0.0633
# Epoch 52/100
# 640/640 [==============================] - 0s 257us/step - loss: 2.5793 - correlation_coefficient: 0.1541 - val_loss: 2.4676 - val_correlation_coefficient: 0.0623
# Epoch 53/100
# 640/640 [==============================] - 0s 271us/step - loss: 2.5594 - correlation_coefficient: 0.1543 - val_loss: 2.4663 - val_correlation_coefficient: 0.0610
# Epoch 54/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.5564 - correlation_coefficient: 0.1367 - val_loss: 2.4384 - val_correlation_coefficient: 0.0584
# Epoch 55/100
# 640/640 [==============================] - 0s 257us/step - loss: 2.5819 - correlation_coefficient: 0.1448 - val_loss: 2.4478 - val_correlation_coefficient: 0.0552
# Epoch 56/100
# 640/640 [==============================] - 0s 265us/step - loss: 2.5554 - correlation_coefficient: 0.1671 - val_loss: 2.4674 - val_correlation_coefficient: 0.0526
# Epoch 57/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.5507 - correlation_coefficient: 0.1603 - val_loss: 2.4704 - val_correlation_coefficient: 0.0484
# Epoch 58/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.5554 - correlation_coefficient: 0.1785 - val_loss: 2.4691 - val_correlation_coefficient: 0.0457
# Epoch 59/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.5588 - correlation_coefficient: 0.1720 - val_loss: 2.5425 - val_correlation_coefficient: 0.0470
# Epoch 60/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.5702 - correlation_coefficient: 0.1529 - val_loss: 2.4530 - val_correlation_coefficient: 0.0465
# Epoch 61/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.5373 - correlation_coefficient: 0.1408 - val_loss: 2.4490 - val_correlation_coefficient: 0.0466
# Epoch 62/100
# 640/640 [==============================] - 0s 279us/step - loss: 2.5338 - correlation_coefficient: 0.1773 - val_loss: 2.5108 - val_correlation_coefficient: 0.0435
# Epoch 63/100
# 640/640 [==============================] - 0s 266us/step - loss: 2.5407 - correlation_coefficient: 0.1462 - val_loss: 2.4564 - val_correlation_coefficient: 0.0424
# Epoch 64/100
# 640/640 [==============================] - 0s 241us/step - loss: 2.5551 - correlation_coefficient: 0.1493 - val_loss: 2.5116 - val_correlation_coefficient: 0.0431
# Epoch 65/100
# 640/640 [==============================] - 0s 274us/step - loss: 2.5404 - correlation_coefficient: 0.1602 - val_loss: 2.4655 - val_correlation_coefficient: 0.0405
# Epoch 66/100
# 640/640 [==============================] - 0s 257us/step - loss: 2.5404 - correlation_coefficient: 0.1651 - val_loss: 2.4587 - val_correlation_coefficient: 0.0372
# Epoch 67/100
# 640/640 [==============================] - 0s 268us/step - loss: 2.5551 - correlation_coefficient: 0.1788 - val_loss: 2.4773 - val_correlation_coefficient: 0.0379
# Epoch 68/100
# 640/640 [==============================] - 0s 265us/step - loss: 2.5248 - correlation_coefficient: 0.1798 - val_loss: 2.4769 - val_correlation_coefficient: 0.0384
# Epoch 69/100
# 640/640 [==============================] - 0s 271us/step - loss: 2.5179 - correlation_coefficient: 0.1606 - val_loss: 2.4816 - val_correlation_coefficient: 0.0413
# Epoch 70/100
# 640/640 [==============================] - 0s 261us/step - loss: 2.5552 - correlation_coefficient: 0.1812 - val_loss: 2.4666 - val_correlation_coefficient: 0.0399
# Epoch 71/100
# 640/640 [==============================] - 0s 276us/step - loss: 2.5795 - correlation_coefficient: 0.1916 - val_loss: 2.6389 - val_correlation_coefficient: 0.0410
# Epoch 72/100
# 640/640 [==============================] - 0s 274us/step - loss: 2.5482 - correlation_coefficient: 0.1792 - val_loss: 2.4619 - val_correlation_coefficient: 0.0395
# Epoch 73/100
# 640/640 [==============================] - 0s 290us/step - loss: 2.5226 - correlation_coefficient: 0.1840 - val_loss: 2.4632 - val_correlation_coefficient: 0.0386
# Epoch 74/100
# 640/640 [==============================] - 0s 231us/step - loss: 2.5139 - correlation_coefficient: 0.1782 - val_loss: 2.4637 - val_correlation_coefficient: 0.0431
# Epoch 75/100
# 640/640 [==============================] - 0s 259us/step - loss: 2.5160 - correlation_coefficient: 0.1749 - val_loss: 2.4742 - val_correlation_coefficient: 0.0438
# Epoch 76/100
# 640/640 [==============================] - 0s 280us/step - loss: 2.5193 - correlation_coefficient: 0.1889 - val_loss: 2.4780 - val_correlation_coefficient: 0.0412
# Epoch 77/100
# 640/640 [==============================] - 0s 277us/step - loss: 2.5062 - correlation_coefficient: 0.1889 - val_loss: 2.4774 - val_correlation_coefficient: 0.0437
# Epoch 78/100
# 640/640 [==============================] - 0s 259us/step - loss: 2.5197 - correlation_coefficient: 0.1967 - val_loss: 2.4765 - val_correlation_coefficient: 0.0443
# Epoch 79/100
# 640/640 [==============================] - 0s 271us/step - loss: 2.5074 - correlation_coefficient: 0.2237 - val_loss: 2.4792 - val_correlation_coefficient: 0.0435
# Epoch 80/100
# 640/640 [==============================] - 0s 264us/step - loss: 2.5093 - correlation_coefficient: 0.2207 - val_loss: 2.4961 - val_correlation_coefficient: 0.0443
# Epoch 81/100
# 640/640 [==============================] - 0s 273us/step - loss: 2.4899 - correlation_coefficient: 0.2163 - val_loss: 2.4963 - val_correlation_coefficient: 0.0483
# Epoch 82/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.5711 - correlation_coefficient: 0.1937 - val_loss: 2.4900 - val_correlation_coefficient: 0.0490
# Epoch 83/100
# 640/640 [==============================] - 0s 270us/step - loss: 2.5288 - correlation_coefficient: 0.1917 - val_loss: 2.5618 - val_correlation_coefficient: 0.0503
# Epoch 84/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.4860 - correlation_coefficient: 0.2094 - val_loss: 2.4914 - val_correlation_coefficient: 0.0482
# Epoch 85/100
# 640/640 [==============================] - 0s 267us/step - loss: 2.5067 - correlation_coefficient: 0.2032 - val_loss: 2.5510 - val_correlation_coefficient: 0.0508
# Epoch 86/100
# 640/640 [==============================] - 0s 274us/step - loss: 2.5435 - correlation_coefficient: 0.2136 - val_loss: 2.4940 - val_correlation_coefficient: 0.0497
# Epoch 87/100
# 640/640 [==============================] - 0s 272us/step - loss: 2.4828 - correlation_coefficient: 0.2163 - val_loss: 2.5356 - val_correlation_coefficient: 0.0481
# Epoch 88/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.4867 - correlation_coefficient: 0.2012 - val_loss: 2.5142 - val_correlation_coefficient: 0.0500
# Epoch 89/100
# 640/640 [==============================] - 0s 261us/step - loss: 2.4987 - correlation_coefficient: 0.2027 - val_loss: 2.5106 - val_correlation_coefficient: 0.0475
# Epoch 90/100
# 640/640 [==============================] - 0s 270us/step - loss: 2.4942 - correlation_coefficient: 0.1878 - val_loss: 2.5104 - val_correlation_coefficient: 0.0485
# Epoch 91/100
# 640/640 [==============================] - 0s 258us/step - loss: 2.4853 - correlation_coefficient: 0.2070 - val_loss: 2.5661 - val_correlation_coefficient: 0.0472
# Epoch 92/100
# 640/640 [==============================] - 0s 269us/step - loss: 2.4856 - correlation_coefficient: 0.2268 - val_loss: 2.5209 - val_correlation_coefficient: 0.0486
# Epoch 93/100
# 640/640 [==============================] - 0s 287us/step - loss: 2.4887 - correlation_coefficient: 0.2305 - val_loss: 2.5181 - val_correlation_coefficient: 0.0498
# Epoch 94/100
# 640/640 [==============================] - 0s 271us/step - loss: 2.4769 - correlation_coefficient: 0.2044 - val_loss: 2.5233 - val_correlation_coefficient: 0.0493
# Epoch 95/100
# 640/640 [==============================] - 0s 253us/step - loss: 2.4959 - correlation_coefficient: 0.2350 - val_loss: 2.5211 - val_correlation_coefficient: 0.0499
# Epoch 96/100
# 640/640 [==============================] - 0s 222us/step - loss: 2.4691 - correlation_coefficient: 0.2327 - val_loss: 2.5259 - val_correlation_coefficient: 0.0507
# Epoch 97/100
# 640/640 [==============================] - 0s 270us/step - loss: 2.4813 - correlation_coefficient: 0.2182 - val_loss: 2.5352 - val_correlation_coefficient: 0.0491
# Epoch 98/100
# 640/640 [==============================] - 0s 275us/step - loss: 2.4657 - correlation_coefficient: 0.2092 - val_loss: 2.5758 - val_correlation_coefficient: 0.0486
# Epoch 99/100
# 640/640 [==============================] - 0s 285us/step - loss: 2.4905 - correlation_coefficient: 0.2200 - val_loss: 2.5396 - val_correlation_coefficient: 0.0487
# Epoch 100/100
# 640/640 [==============================] - 0s 278us/step - loss: 2.4762 - correlation_coefficient: 0.2439 - val_loss: 2.5349 - val_correlation_coefficient: 0.0499
# [root    |INFO|build_network.py:83] Load trained model weight at ./weight_1.h5
# [root    |INFO|build_network.py:143] Training end with time 19.152787685394287!
# [root    |INFO|build_network.py:79] Saved trained model weight at ./weight_1.h5
# [root    |DEBUG|deepbiome.py:166] Save weight at ./weight_1.h5
# [root    |DEBUG|deepbiome.py:169] Save history at ./hist_1.json
# [root    |INFO|build_network.py:169] Evaluation start!
# 800/800 [==============================] - 0s 5us/step
# [root    |INFO|build_network.py:174] Evaluation end with time 0.007260560989379883!
# [root    |INFO|build_network.py:175] Evaluation: [2.5466859340667725, 0.07888418436050415]
# [root    |INFO|build_network.py:169] Evaluation start!
# 200/200 [==============================] - 0s 19us/step
# [root    |INFO|build_network.py:174] Evaluation end with time 0.006544589996337891!
# [root    |INFO|build_network.py:175] Evaluation: [2.5354177951812744, -0.022087521851062775]
# [root    |INFO|deepbiome.py:180] Compute time : 20.05062985420227
# [root    |INFO|deepbiome.py:181] 2 fold computing end!---------------------------------------------
# [root    |INFO|deepbiome.py:184] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:186] Train Evaluation : ['loss' 'correlation_coefficient']
# [root    |INFO|deepbiome.py:189]       mean : [1.9532609  0.39732546]
# [root    |INFO|deepbiome.py:190]        std : [0.59342504 0.31844127]
# [root    |INFO|deepbiome.py:191] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:193] Test Evaluation : ['loss' 'correlation_coefficient']
# [root    |INFO|deepbiome.py:196]       mean : [2.12202841 0.31917292]
# [root    |INFO|deepbiome.py:197]        std : [0.41338938 0.34126044]
# [root    |INFO|deepbiome.py:198] -----------------------------------------------------------------
# [root    |INFO|deepbiome.py:207] Total Computing Ended
# [root    |INFO|deepbiome.py:208] -----------------------------------------------------------------
